# %% [markdown]
# # Traffic Sign Classification with Keras
#
# Keras exists to make coding deep neural networks simpler. To demonstrate just how easy it is, you’re going to use Keras to build a convolutional neural network in a few dozen lines of code.
#
# You’ll be connecting the concepts from the previous lessons to the methods that Keras provides.

# %% [markdown]
# ## Dataset
#
# The network you'll build with Keras is similar to the example that you can find in Keras’s GitHub repository that builds out a [convolutional neural network for MNIST](https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py).
#
# However, instead of using the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, you're going to use the [German Traffic Sign Recognition Benchmark](http://benchmark.ini.rub.de/?section=gtsrb&subsection=news) dataset that you've used previously.
#
# You can download pickle files with sanitized traffic sign data here.

# %% [markdown]
# ## Overview
#
# Here are the steps you'll take to build the network:
#
# 1. First load the data.
# 2. Build a feedforward neural network to classify traffic signs.
# 3. Build a convolutional neural network to classify traffic signs.
#
# Keep an eye on the network’s accuracy over time. Once the accuracy reaches the 98% range, you can be confident that you’ve built and trained an effective model.

# %% [markdown]
# ## Load the Data
#
# Start by importing the data from the pickle file.

# %%
import keras

# %%
# Load pickled data
import pickle
import os
import numpy as np
from sklearn.model_selection import train_test_split

# TODO: fill this in based on where you saved the training and testing data
training_file = './train.p'
testing_file = './test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

# STOP: Do not change the tests below. Your implementation should pass these tests. 
assert(X_train.shape[0] == y_train.shape[0]), "The number of images is not equal to the number of labels."
assert(X_train.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."

# %% [markdown]
# ## Normalize the data
#
# Now that you've loaded the training data, normalize the input so that it has a mean of 0 and a range between -0.5 and 0.5.

# %%
# TODO: Implement data normalization here.
def normalize_images(X):
    """
    Normalize the image data with Min-Max scaling to a range of [-0.5, 0.5]
    :param image_data: The image data to be normalized
    :return: Normalized image data
    """
    a = -0.5;b = 0.5; Xmin = 0.0;Xmax = 255.0;
    Xm=np.mean(X)
    Xp = X - Xm
    Xmin=np.min(Xp)
    Xmax=np.max(Xp)
    Xp = a + (Xp-Xmin)*(b-a)/(Xmax-Xmin)
    return Xp

X_train=normalize_images(X_train)
X_test=normalize_images(X_test)

# one-hot encoding of labels
def to_categorical(y, nb_classes=None):
    '''Convert class vector (integers from 0 to nb_classes) to binary class matrix, for use with categorical_crossentropy.
    # Arguments
        y: class vector to be converted into a matrix
        nb_classes: total number of classes
    # Returns
        A binary matrix representation of the input.
    '''
    y = np.array(y, dtype='int')
    if not nb_classes:
        nb_classes = np.max(y)+1
    Y = np.zeros((len(y), nb_classes))
    for i in range(len(y)):
        Y[i, y[i]] = 1.
    return Y

Y_train = to_categorical(y_train)
Y_test  = to_categorical(y_test)

# split training set in validation and a new training set
X_train, X_val, Y_train, Y_val = train_test_split(
    X_train, Y_train, test_size=0.25, random_state=42)


# STOP: Do not change the tests below. Your implementation should pass these tests. 
assert(round(np.mean(X_train)) == 0), "The mean of the input data is: %f" % np.mean(X_train)
assert(np.min(X_train) == -0.5 and np.max(X_train) == 0.5), "The range of the input data is: %.1f to %.1f" % (np.min(X_train), np.max(X_train))

# %%
# Save the data for easy access
pickle_file = 'preprocessed_data.p'
if not os.path.isfile(pickle_file):
    print('Saving data to pickle file...')
    try:
        with open(pickle_file, 'wb') as pfile:
            pickle.dump(
                {
                    'X_train': X_train,
                    'Y_train': Y_train,
                    'X_val': X_val,
                    'Y_val': Y_val,
                    'X_test': X_test,
                    'Y_test': Y_test
                },
                pfile, pickle.HIGHEST_PROTOCOL)
    except Exception as e:
        print('Unable to save data to', pickle_file, ':', e)
        raise

print('Data cached in pickle file.')

# %% [markdown]
# ## Build a Two-Layer Feedfoward Network
#
# The code you've written so far is for data processing, not specific to Keras. Here you're going to build Keras-specific code.
#
# Build a two-layer feedforward neural network, with 128 neurons in the fully-connected hidden layer.
#
# To get started, review the Keras documentation about [models](https://keras.io/models/sequential/) and [layers](https://keras.io/layers/core/).
#
# The Keras example of a [Multi-Layer Perceptron](https://github.com/fchollet/keras/blob/master/examples/mnist_mlp.py) network is similar to what you need to do here. Use that as a guide, but keep in mind that there are a number of differences.

# %%
import pickle
pickle_file = 'preprocessed_data.p'

with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train = pickle_data['X_train']
    Y_train = pickle_data['Y_train']
    X_val = pickle_data['X_val']
    Y_val = pickle_data['Y_val']
    X_test = pickle_data['X_test']
    Y_test = pickle_data['Y_test']
    del pickle_data  # Free up memory

print('Data and modules loaded.')

# %%
# TODO: Build a two-layer feedforward neural network with Keras here.
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam

input_dim=32*32*3
nb_classes=43

model = Sequential()
model.add(Dense(128, input_dim=input_dim, name='hidden1'))
model.add(Activation('relu'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax'))

model.summary()

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(model.get_layer(name="hidden1").input_shape == (None, 32*32*3)), "The input shape is: %s" % model.get_layer(name="hidden1").input_shape
assert(model.get_layer(name="output").output_shape == (None, 43)), "The output shape is: %s" % model.get_layer(name="output").output_shape

# %% [markdown]
# ## Train the Network
# Compile and train the network for 2 epochs. [Use the `adam` optimizer, with `categorical_crossentropy` loss.](https://keras.io/models/sequential/)
#
# Hint 1: In order to use categorical cross entropy, you will need to [one-hot encode the labels](https://github.com/fchollet/keras/blob/master/keras/utils/np_utils.py).
#
# Hint 2: In order to pass the input images to the fully-connected hidden layer, you will need to [reshape the input](https://github.com/fchollet/keras/blob/master/examples/mnist_mlp.py).
#
# Hint 3: Keras's `.fit()` method returns a `History.history` object, which the tests below use. Save that to a variable named `history`.

# %%
X_train = X_train.reshape(-1, input_dim)
print(X_train.shape)
X_val = X_val.reshape(-1, input_dim)
print(X_val.shape)

# %%
batch_size = 128
nb_epoch = 2

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_train, Y_train))

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(history.history['acc'][0] > 0.5), "The training accuracy was: %.3f" % history.history['acc']

# %% [markdown]
# ## Validate the Network
# Split the training data into a training and validation set.
#
# Measure the [validation accuracy](https://keras.io/models/sequential/) of the network after two training epochs.
#
# Hint: [Use the `train_test_split()` method](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) from scikit-learn.

# %%
# TODO: Compile and train the model to measure validation accuracy.

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_val, Y_val))

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(round(X_train.shape[0] / float(X_val.shape[0])) == 3), "The training set is %.3f times larger than the validation set." % X_train.shape[0] / float(X_val.shape[0])
assert(history.history['val_acc'][0] > 0.6), "The validation accuracy is: %.3f" % history.history['val_acc'][0]

# %% [markdown]
# **Validation Accuracy**: 0.87

# %% [markdown]
# ## Congratulations
# You've built a feedforward neural network in Keras!
#
# Don't stop here! Next, you'll add a convolutional layer to drive.py.

# %% [markdown]
# ## Convolutions
# Build a new network, similar to your existing network. Before the hidden layer, add a 3x3 [convolutional layer](https://keras.io/layers/convolutional/#convolution2d) with 32 filters and valid padding.
#
# Then compile and train the network.
#
# Hint 1: The Keras example of a [convolutional neural network](https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py) for MNIST would be a good example to review.
#
# Hint 2: Now that the first layer of the network is a convolutional layer, you no longer need to reshape the input images before passing them to the network. You might need to reload your training data to recover the original shape.
#
# Hint 3: Add a [`Flatten()` layer](https://keras.io/layers/core/#flatten) between the convolutional layer and the fully-connected hidden layer.

# %%
import pickle
import numpy as np

pickle_file = 'preprocessed_data.p'

with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train = pickle_data['X_train']
    Y_train = pickle_data['Y_train']
    X_val = pickle_data['X_val']
    Y_val = pickle_data['Y_val']
    X_test = pickle_data['X_test']
    Y_test = pickle_data['Y_test']
    del pickle_data  # Free up memory

print('Data and modules loaded.')


# STOP: Do not change the tests below. Your implementation should pass these tests. 
assert(X_train.shape[0] == Y_train.shape[0]), "The number of images is not equal to the number of labels."
assert(X_train.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."

# %%
# TODO: Re-construct the network and add a convolutional layer before the first fully-connected layer.
# TODO: Compile and train the model.
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam

# number of classes
nb_classes = 43
# input image dimensions
img_rows, img_cols, img_ch = 32, 32, 3
# number of convolutional filters to use and theird
nb_filter = 32
# convolution kernel size
kernel_size = (3, 3)

model = Sequential()
model.add(Convolution2D(nb_filter, kernel_size[0], kernel_size[1], 
                        border_mode='valid', 
                        input_shape=(img_rows,img_cols,img_ch),
                        name='conv1'))
model.add(Activation('relu',name='relu1'))
model.add(Flatten())
model.add(Dense(128, name='hidden1'))
model.add(Activation('relu',name='relu2'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

# %%
# number of epochs to train
nb_epoch=2
#batch size
batch_size = 128

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_val, Y_val))

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(history.history['val_acc'][0] > 0.9), "The validation accuracy is: %.3f" % history.history['val_acc'][0]

# %% [markdown]
# **Validation Accuracy**: 0.95

# %% [markdown]
# ## Pooling
# Re-construct your network and add a 2x2 [pooling layer](https://keras.io/layers/pooling/#maxpooling2d) immediately following your convolutional layer.
#
# Then compile and train the network.

# %%
import pickle
import numpy as np

pickle_file = 'preprocessed_data.p'

with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train = pickle_data['X_train']
    Y_train = pickle_data['Y_train']
    X_val = pickle_data['X_val']
    Y_val = pickle_data['Y_val']
    X_test = pickle_data['X_test']
    Y_test = pickle_data['Y_test']
    del pickle_data  # Free up memory

print('Data and modules loaded.')

# STOP: Do not change the tests below. Your implementation should pass these tests. 
assert(X_train.shape[0] == Y_train.shape[0]), "The number of images is not equal to the number of labels."
assert(X_train.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."

# %%
# TODO: Re-construct the network and add a pooling layer after the convolutional layer.
from keras.models import Sequential
from keras.layers import Dense, Activation,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam

# number of classes
nb_classes = 43
# input image dimensions
img_rows, img_cols, img_ch = 32, 32, 3
# number of convolutional filters to use and theird
nb_filter = 32
# size of pooling area for max pooling
pool_size = (2, 2)
# convolution kernel size
kernel_size = (3, 3)


model = Sequential()
model.add(Convolution2D(nb_filter, kernel_size[0], kernel_size[1],border_mode='valid', 
                        input_shape=(img_rows,img_cols,img_ch),name='conv1'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Activation('relu',name='relu1'))
model.add(Flatten())
model.add(Dense(128, input_dim=input_dim, name='hidden1'))
model.add(Activation('relu',name='relu3'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()


adam = Adam(lr=1e-04, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

# %%
nb_epoch=10
batch_size=128

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_val, Y_val))

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(history.history['val_acc'][0] > 0.9), "The validation accuracy is: %.3f" % history.history['val_acc'][0]

# %%
model.save('models/TrafficSigns_1conv_1pool.ckpt')

# %% [markdown]
# **Validation Accuracy**: 0.94

# %% [markdown]
# ## Dropout
# Re-construct your network and add [dropout](https://keras.io/layers/core/#dropout) after the pooling layer. Set the dropout rate to 50%.

# %%
import pickle
import numpy as np

pickle_file = 'preprocessed_data.p'

with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train = pickle_data['X_train']
    Y_train = pickle_data['Y_train']
    X_val = pickle_data['X_val']
    Y_val = pickle_data['Y_val']
    X_test = pickle_data['X_test']
    Y_test = pickle_data['Y_test']
    del pickle_data  # Free up memory

print('Data and modules loaded.')

# STOP: Do not change the tests below. Your implementation should pass these tests. 
assert(X_train.shape[0] == Y_train.shape[0]), "The number of images is not equal to the number of labels."
assert(X_train.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."
# Out:
# Data and modules loaded.

# %%
# TODO: Re-construct the netMaxPooling2Dwork and add dropout after the pooling layer.
# TODO: Compile and train the model.
import os
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam


# number of classes
nb_classes = 43
# input image dimensions
img_rows, img_cols, img_ch = 32, 32, 3
# number of convolutional filters to use and theird
nb_filter = 32
# size of pooling area for max pooling
pool_size = (2, 2)
# convolution kernel size
kernel_size = (3, 3)


model = Sequential()
model.add(Convolution2D(nb_filter, kernel_size[0], kernel_size[1],border_mode='valid', 
                        input_shape=(img_rows,img_cols,img_ch),name='conv1'))
model.add(Activation('relu',name='relu1'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(128, name='hidden1'))
model.add(Activation('relu',name='relu2'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()
# Out:
# Using TensorFlow backend.
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# conv1 (Convolution2D)            (None, 30, 30, 32)    896         convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# relu1 (Activation)               (None, 30, 30, 32)    0           conv1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 15, 15, 32)    0           relu1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 15, 15, 32)    0           maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 7200)          0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# hidden1 (Dense)                  (None, 128)           921728      flatten_1[0][0]
# ____________________________________________________________________________________________________
# relu2 (Activation)               (None, 128)           0           hidden1[0][0]
# ____________________________________________________________________________________________________
# output (Dense)                   (None, 43)            5547        relu2[0][0]
# ____________________________________________________________________________________________________
# softmax (Activation)             (None, 43)            0           output[0][0]
# ====================================================================================================
# Total params: 928171
# ____________________________________________________________________________________________________

# %%
from keras.models import load_model
nb_epoch = 2
batch_size=128

model_name='models/TrafficSigns_1conv_1pool_1dropout.ckpt'

if os.path.isfile(model_name):
    try:
        model = load_model(model_name)
        print('loading trained model ...')
    except Exception as e:
        print('Unable to load model', model_name, ':', e)
        raise    


adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_val, Y_val))

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(history.history['val_acc'][-1] > 0.9), "The validation accuracy is: %.3f" % history.history['val_acc'][-1]
# Out:
# loading trained model ...
# Train on 29406 samples, validate on 9803 samples
# Epoch 1/2
# 29406/29406 [==============================] - 2s - loss: 0.1888 - acc: 0.9501 - val_loss: 0.1616 - val_acc: 0.9648
# Epoch 2/2
# 29406/29406 [==============================] - 1s - loss: 0.1479 - acc: 0.9598 - val_loss: 0.1340 - val_acc: 0.9682

# %%
model.save('models/TrafficSigns_1conv_1pool_1dropout.ckpt')

# %% [markdown]
# **Validation Accuracy**: 0.95

# %% [markdown]
# ## Optimization
# Congratulations! You've built a neural network with convolutions, pooling, dropout, and fully-connected layers, all in just a few lines of code.
#
# Have fun with the model and see how well you can do! Add more layers, or regularization, or different padding, or batches, or more training epochs.
#
# What is the best validation accuracy you can achieve?

# %%
import pickle
import numpy as np

pickle_file = 'preprocessed_data.p'

with open(pickle_file, 'rb') as f:
    pickle_data = pickle.load(f)
    X_train = pickle_data['X_train']
    Y_train = pickle_data['Y_train']
    X_val = pickle_data['X_val']
    Y_val = pickle_data['Y_val']
    X_test = pickle_data['X_test']
    Y_test = pickle_data['Y_test']
    del pickle_data  # Free up memory

print('Data and modules loaded.')

# STOP: Do not change the tests below. Your implementation should pass these tests. 
assert(X_train.shape[0] == Y_train.shape[0]), "The number of images is not equal to the number of labels."
assert(X_train.shape[1:] == (32,32,3)), "The dimensions of the images are not 32 x 32 x 3."
# Out:
# Data and modules loaded.

# %%
import os
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam


# number of classes
nb_classes = 43
# input image dimensions
img_rows, img_cols, img_ch = 32, 32, 3
# number of convolutional filters to use
nb_filter1 = 32
nb_filter2 = 64
nb_filter3 = 128
# size of pooling area for max pooling
pool_size = (2, 2)
pool_strides = (1,1)
# convolution kernel size
kernel_size = (5, 5)
# number of hidden units in the first fully connected layer
nb_fc1=128
nb_fc2=128


model = Sequential()
model.add(Convolution2D(nb_filter1, kernel_size[0], kernel_size[1],border_mode='same', subsample=(1,1),
                        input_shape=(img_rows,img_cols,img_ch),name='conv1'))
model.add(Activation('relu',name='relu1'))
model.add(MaxPooling2D(pool_size=pool_size,strides=pool_strides,name='maxpool1'))
model.add(Convolution2D(nb_filter2, kernel_size[0], kernel_size[1],border_mode='same',subsample=(1,1),
                        name='conv2'))
model.add(Activation('relu',name='relu2'))
model.add(MaxPooling2D(pool_size=pool_size,strides=None,name='maxpool2'))
model.add(Convolution2D(nb_filter2, kernel_size[0], kernel_size[1],border_mode='same',subsample=(1,1),
                        name='conv3'))
model.add(Activation('relu',name='relu3'))
model.add(MaxPooling2D(pool_size=pool_size,strides=None,name='maxpool3'))
model.add(Flatten(name='flatten'))
model.add(Dropout(0.5,name='dropout1'))
model.add(Dense(nb_fc1, name='hidden1'))
model.add(Activation('relu',name='relu4'))
model.add(Dropout(0.5,name='dropout2'))
model.add(Dense(nb_fc2,  name='hidden2'))
model.add(Activation('relu',name='relu5'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()
# Out:
# Using TensorFlow backend.
# loading trained model ...
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# conv1 (Convolution2D)            (None, 32, 32, 32)    2432        convolution2d_input_2[0][0]
# ____________________________________________________________________________________________________
# relu1 (Activation)               (None, 32, 32, 32)    0           conv1[0][0]
# ____________________________________________________________________________________________________
# maxpool1 (MaxPooling2D)          (None, 31, 31, 32)    0           relu1[0][0]
# ____________________________________________________________________________________________________
# conv2 (Convolution2D)            (None, 31, 31, 64)    51264       maxpool1[0][0]
# ____________________________________________________________________________________________________
# relu2 (Activation)               (None, 31, 31, 64)    0           conv2[0][0]
# ____________________________________________________________________________________________________
# maxpool2 (MaxPooling2D)          (None, 15, 15, 64)    0           relu2[0][0]
# ____________________________________________________________________________________________________
# conv3 (Convolution2D)            (None, 15, 15, 64)    102464      maxpool2[0][0]
# ____________________________________________________________________________________________________
# relu3 (Activation)               (None, 15, 15, 64)    0           conv3[0][0]
# ____________________________________________________________________________________________________
# maxpool3 (MaxPooling2D)          (None, 7, 7, 64)      0           relu3[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 3136)          0           maxpool3[0][0]
# ____________________________________________________________________________________________________
# dropout1 (Dropout)               (None, 3136)          0           flatten[0][0]
# ____________________________________________________________________________________________________
# hidden1 (Dense)                  (None, 128)           401536      dropout1[0][0]
# ____________________________________________________________________________________________________
# relu4 (Activation)               (None, 128)           0           hidden1[0][0]
# ____________________________________________________________________________________________________
# dropout2 (Dropout)               (None, 128)           0           relu4[0][0]
# ____________________________________________________________________________________________________
# hidden2 (Dense)                  (None, 128)           16512       dropout2[0][0]
# ____________________________________________________________________________________________________
# relu5 (Activation)               (None, 128)           0           hidden2[0][0]
# ____________________________________________________________________________________________________
# output (Dense)                   (None, 43)            5547        relu5[0][0]
# ____________________________________________________________________________________________________
# softmax (Activation)             (None, 43)            0           output[0][0]
# ====================================================================================================
# Total params: 579755
# ____________________________________________________________________________________________________

# %%
nb_epoch = 1000
batch_size=128

model_name='models/TrafficSigns_3conv_3pool_2dropout.ckpt'

if os.path.isfile(model_name):
    try:
        model = load_model(model_name)
        print('loading trained model ...')
    except Exception as e:
        print('Unable to load model', model_name, ':', e)
        raise    


adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=2, validation_data=(X_val, Y_val))

# STOP: Do not change the tests below. Your implementation should pass these tests.
assert(history.history['val_acc'][-1] > 0.9), "The validation accuracy is: %.3f" % history.history['val_acc'][-1]
# Out:
# loading trained model ...
# Train on 29406 samples, validate on 9803 samples
# Epoch 1/1000
# 6s - loss: 0.0213 - acc: 0.9932 - val_loss: 0.0158 - val_acc: 0.9969
# Epoch 2/1000
# 5s - loss: 0.0199 - acc: 0.9943 - val_loss: 0.0153 - val_acc: 0.9971
# Epoch 3/1000
# 5s - loss: 0.0218 - acc: 0.9928 - val_loss: 0.0169 - val_acc: 0.9969
# Epoch 4/1000
# 5s - loss: 0.0193 - acc: 0.9939 - val_loss: 0.0166 - val_acc: 0.9967
# Epoch 5/1000
# 5s - loss: 0.0189 - acc: 0.9935 - val_loss: 0.0165 - val_acc: 0.9970
# Epoch 6/1000
# 5s - loss: 0.0169 - acc: 0.9944 - val_loss: 0.0171 - val_acc: 0.9968
# Epoch 7/1000
# 5s - loss: 0.0174 - acc: 0.9948 - val_loss: 0.0157 - val_acc: 0.9969
# Epoch 8/1000
# 5s - loss: 0.0187 - acc: 0.9943 - val_loss: 0.0164 - val_acc: 0.9970
# Epoch 9/1000
# 5s - loss: 0.0166 - acc: 0.9944 - val_loss: 0.0157 - val_acc: 0.9971
# Epoch 10/1000
# 5s - loss: 0.0191 - acc: 0.9940 - val_loss: 0.0148 - val_acc: 0.9972
# Epoch 11/1000
# 5s - loss: 0.0186 - acc: 0.9938 - val_loss: 0.0164 - val_acc: 0.9970
# Epoch 12/1000
# 5s - loss: 0.0172 - acc: 0.9947 - val_loss: 0.0166 - val_acc: 0.9969
# Epoch 13/1000
# 5s - loss: 0.0175 - acc: 0.9944 - val_loss: 0.0153 - val_acc: 0.9970
# Epoch 14/1000
# 5s - loss: 0.0171 - acc: 0.9944 - val_loss: 0.0154 - val_acc: 0.9976
# Epoch 15/1000
# 5s - loss: 0.0177 - acc: 0.9944 - val_loss: 0.0152 - val_acc: 0.9972
# Epoch 16/1000
# 5s - loss: 0.0177 - acc: 0.9941 - val_loss: 0.0158 - val_acc: 0.9970
# Epoch 17/1000
# 5s - loss: 0.0158 - acc: 0.9952 - val_loss: 0.0137 - val_acc: 0.9976
# Epoch 18/1000
# 5s - loss: 0.0181 - acc: 0.9939 - val_loss: 0.0146 - val_acc: 0.9971
# Epoch 19/1000
# 5s - loss: 0.0157 - acc: 0.9951 - val_loss: 0.0150 - val_acc: 0.9974
# Epoch 20/1000
# 5s - loss: 0.0172 - acc: 0.9947 - val_loss: 0.0159 - val_acc: 0.9972
# Epoch 21/1000
# 5s - loss: 0.0156 - acc: 0.9952 - val_loss: 0.0153 - val_acc: 0.9971
# Epoch 22/1000
# 5s - loss: 0.0148 - acc: 0.9950 - val_loss: 0.0138 - val_acc: 0.9978
# Epoch 23/1000
# 5s - loss: 0.0175 - acc: 0.9945 - val_loss: 0.0140 - val_acc: 0.9972
# Epoch 24/1000
# 5s - loss: 0.0153 - acc: 0.9949 - val_loss: 0.0149 - val_acc: 0.9972
# Epoch 25/1000
# 5s - loss: 0.0142 - acc: 0.9949 - val_loss: 0.0148 - val_acc: 0.9977
# Epoch 26/1000
# 5s - loss: 0.0144 - acc: 0.9953 - val_loss: 0.0156 - val_acc: 0.9972
# Epoch 27/1000
# 5s - loss: 0.0158 - acc: 0.9950 - val_loss: 0.0144 - val_acc: 0.9972
# Epoch 28/1000
# 5s - loss: 0.0125 - acc: 0.9954 - val_loss: 0.0147 - val_acc: 0.9976
# Epoch 29/1000
# 5s - loss: 0.0128 - acc: 0.9961 - val_loss: 0.0152 - val_acc: 0.9976
# Epoch 30/1000
# 5s - loss: 0.0152 - acc: 0.9953 - val_loss: 0.0143 - val_acc: 0.9971
# Epoch 31/1000
# 5s - loss: 0.0133 - acc: 0.9960 - val_loss: 0.0149 - val_acc: 0.9974
# Epoch 32/1000
# 6s - loss: 0.0137 - acc: 0.9961 - val_loss: 0.0147 - val_acc: 0.9976
# Epoch 33/1000
# 5s - loss: 0.0142 - acc: 0.9958 - val_loss: 0.0152 - val_acc: 0.9973
# Epoch 34/1000
# 5s - loss: 0.0129 - acc: 0.9958 - val_loss: 0.0146 - val_acc: 0.9970
# Epoch 35/1000
# 5s - loss: 0.0141 - acc: 0.9953 - val_loss: 0.0149 - val_acc: 0.9978
# Epoch 36/1000
# 5s - loss: 0.0150 - acc: 0.9950 - val_loss: 0.0143 - val_acc: 0.9973
# Epoch 37/1000
# 5s - loss: 0.0135 - acc: 0.9958 - val_loss: 0.0146 - val_acc: 0.9974
# Epoch 38/1000
# 5s - loss: 0.0128 - acc: 0.9960 - val_loss: 0.0133 - val_acc: 0.9977
# Epoch 39/1000
# 5s - loss: 0.0130 - acc: 0.9961 - val_loss: 0.0133 - val_acc: 0.9976
# Epoch 40/1000
# 5s - loss: 0.0113 - acc: 0.9965 - val_loss: 0.0142 - val_acc: 0.9972
# Epoch 41/1000
# 5s - loss: 0.0111 - acc: 0.9965 - val_loss: 0.0157 - val_acc: 0.9970
# Epoch 42/1000
# 5s - loss: 0.0137 - acc: 0.9957 - val_loss: 0.0140 - val_acc: 0.9976
# Epoch 43/1000
# 5s - loss: 0.0136 - acc: 0.9953 - val_loss: 0.0154 - val_acc: 0.9977
# Epoch 44/1000
# 5s - loss: 0.0130 - acc: 0.9960 - val_loss: 0.0162 - val_acc: 0.9971
# Epoch 45/1000
# 5s - loss: 0.0111 - acc: 0.9963 - val_loss: 0.0147 - val_acc: 0.9977
# Epoch 46/1000
# 5s - loss: 0.0107 - acc: 0.9967 - val_loss: 0.0144 - val_acc: 0.9976
# Epoch 47/1000
# 5s - loss: 0.0140 - acc: 0.9962 - val_loss: 0.0146 - val_acc: 0.9976
# Epoch 48/1000
# 5s - loss: 0.0127 - acc: 0.9960 - val_loss: 0.0152 - val_acc: 0.9978
# Epoch 49/1000
# 5s - loss: 0.0134 - acc: 0.9960 - val_loss: 0.0134 - val_acc: 0.9976
# Epoch 50/1000
# 5s - loss: 0.0106 - acc: 0.9969 - val_loss: 0.0139 - val_acc: 0.9977
# Epoch 51/1000
# 5s - loss: 0.0110 - acc: 0.9968 - val_loss: 0.0146 - val_acc: 0.9978
# Epoch 52/1000
# 5s - loss: 0.0100 - acc: 0.9970 - val_loss: 0.0152 - val_acc: 0.9976
# Epoch 53/1000
# 5s - loss: 0.0115 - acc: 0.9963 - val_loss: 0.0164 - val_acc: 0.9974
# Epoch 54/1000
# 5s - loss: 0.0114 - acc: 0.9963 - val_loss: 0.0148 - val_acc: 0.9976
# Epoch 55/1000
# 5s - loss: 0.0112 - acc: 0.9964 - val_loss: 0.0153 - val_acc: 0.9976
# Epoch 56/1000
# 5s - loss: 0.0118 - acc: 0.9965 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 57/1000
# 5s - loss: 0.0104 - acc: 0.9974 - val_loss: 0.0150 - val_acc: 0.9976
# Epoch 58/1000
# 5s - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0158 - val_acc: 0.9974
# Epoch 59/1000
# 5s - loss: 0.0117 - acc: 0.9963 - val_loss: 0.0144 - val_acc: 0.9971
# Epoch 60/1000
# 5s - loss: 0.0103 - acc: 0.9969 - val_loss: 0.0137 - val_acc: 0.9978
# Epoch 61/1000
# 5s - loss: 0.0102 - acc: 0.9968 - val_loss: 0.0133 - val_acc: 0.9978
# Epoch 62/1000
# 5s - loss: 0.0111 - acc: 0.9967 - val_loss: 0.0136 - val_acc: 0.9978
# Epoch 63/1000
# 5s - loss: 0.0113 - acc: 0.9966 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 64/1000
# 6s - loss: 0.0110 - acc: 0.9961 - val_loss: 0.0156 - val_acc: 0.9979
# Epoch 65/1000
# 5s - loss: 0.0107 - acc: 0.9966 - val_loss: 0.0149 - val_acc: 0.9974
# Epoch 66/1000
# 5s - loss: 0.0106 - acc: 0.9965 - val_loss: 0.0141 - val_acc: 0.9977
# Epoch 67/1000
# 5s - loss: 0.0086 - acc: 0.9973 - val_loss: 0.0140 - val_acc: 0.9976
# Epoch 68/1000
# 5s - loss: 0.0096 - acc: 0.9968 - val_loss: 0.0134 - val_acc: 0.9980
# Epoch 69/1000
# 5s - loss: 0.0097 - acc: 0.9973 - val_loss: 0.0132 - val_acc: 0.9980
# Epoch 70/1000
# 5s - loss: 0.0106 - acc: 0.9967 - val_loss: 0.0148 - val_acc: 0.9976
# Epoch 71/1000
# 5s - loss: 0.0100 - acc: 0.9969 - val_loss: 0.0143 - val_acc: 0.9977
# Epoch 72/1000
# 5s - loss: 0.0103 - acc: 0.9967 - val_loss: 0.0155 - val_acc: 0.9970
# Epoch 73/1000
# 5s - loss: 0.0121 - acc: 0.9959 - val_loss: 0.0139 - val_acc: 0.9977
# Epoch 74/1000
# 5s - loss: 0.0102 - acc: 0.9970 - val_loss: 0.0162 - val_acc: 0.9974
# Epoch 75/1000
# 5s - loss: 0.0116 - acc: 0.9964 - val_loss: 0.0153 - val_acc: 0.9977
# Epoch 76/1000
# 5s - loss: 0.0096 - acc: 0.9971 - val_loss: 0.0135 - val_acc: 0.9978
# Epoch 77/1000
# 5s - loss: 0.0091 - acc: 0.9970 - val_loss: 0.0150 - val_acc: 0.9979
# Epoch 78/1000
# 5s - loss: 0.0076 - acc: 0.9974 - val_loss: 0.0133 - val_acc: 0.9974
# Epoch 79/1000
# 5s - loss: 0.0108 - acc: 0.9966 - val_loss: 0.0139 - val_acc: 0.9976
# Epoch 80/1000
# 5s - loss: 0.0096 - acc: 0.9966 - val_loss: 0.0138 - val_acc: 0.9978
# Epoch 81/1000
# 5s - loss: 0.0110 - acc: 0.9968 - val_loss: 0.0133 - val_acc: 0.9977
# Epoch 82/1000
# 5s - loss: 0.0094 - acc: 0.9974 - val_loss: 0.0142 - val_acc: 0.9978
# Epoch 83/1000
# 5s - loss: 0.0097 - acc: 0.9969 - val_loss: 0.0138 - val_acc: 0.9978
# Epoch 84/1000
# 5s - loss: 0.0078 - acc: 0.9977 - val_loss: 0.0141 - val_acc: 0.9978
# Epoch 85/1000
# 5s - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0139 - val_acc: 0.9976
# Epoch 86/1000
# 5s - loss: 0.0092 - acc: 0.9971 - val_loss: 0.0128 - val_acc: 0.9978
# Epoch 87/1000
# 5s - loss: 0.0092 - acc: 0.9971 - val_loss: 0.0153 - val_acc: 0.9976
# Epoch 88/1000
# 5s - loss: 0.0100 - acc: 0.9967 - val_loss: 0.0153 - val_acc: 0.9976
# Epoch 89/1000
# 5s - loss: 0.0083 - acc: 0.9969 - val_loss: 0.0151 - val_acc: 0.9974
# Epoch 90/1000
# 5s - loss: 0.0085 - acc: 0.9971 - val_loss: 0.0165 - val_acc: 0.9972
# Epoch 91/1000
# 5s - loss: 0.0078 - acc: 0.9975 - val_loss: 0.0139 - val_acc: 0.9979
# Epoch 92/1000
# 5s - loss: 0.0084 - acc: 0.9975 - val_loss: 0.0151 - val_acc: 0.9972
# Epoch 93/1000
# 5s - loss: 0.0068 - acc: 0.9974 - val_loss: 0.0155 - val_acc: 0.9976
# Epoch 94/1000
# 5s - loss: 0.0084 - acc: 0.9974 - val_loss: 0.0138 - val_acc: 0.9978
# Epoch 95/1000
# 5s - loss: 0.0083 - acc: 0.9976 - val_loss: 0.0152 - val_acc: 0.9979
# Epoch 96/1000
# 5s - loss: 0.0078 - acc: 0.9976 - val_loss: 0.0136 - val_acc: 0.9980
# Epoch 97/1000
# 5s - loss: 0.0087 - acc: 0.9974 - val_loss: 0.0147 - val_acc: 0.9977
# Epoch 98/1000
# 5s - loss: 0.0080 - acc: 0.9976 - val_loss: 0.0141 - val_acc: 0.9976
# Epoch 99/1000
# 5s - loss: 0.0078 - acc: 0.9976 - val_loss: 0.0133 - val_acc: 0.9976
# Epoch 100/1000
# 5s - loss: 0.0088 - acc: 0.9974 - val_loss: 0.0169 - val_acc: 0.9971
# Epoch 101/1000
# 5s - loss: 0.0072 - acc: 0.9979 - val_loss: 0.0124 - val_acc: 0.9979
# Epoch 102/1000
# 5s - loss: 0.0071 - acc: 0.9978 - val_loss: 0.0150 - val_acc: 0.9974
# Epoch 103/1000
# 5s - loss: 0.0060 - acc: 0.9981 - val_loss: 0.0130 - val_acc: 0.9978
# Epoch 104/1000
# 5s - loss: 0.0072 - acc: 0.9973 - val_loss: 0.0135 - val_acc: 0.9980
# Epoch 105/1000
# 5s - loss: 0.0073 - acc: 0.9976 - val_loss: 0.0149 - val_acc: 0.9978
# Epoch 106/1000
# 5s - loss: 0.0072 - acc: 0.9976 - val_loss: 0.0157 - val_acc: 0.9978
# Epoch 107/1000
# 5s - loss: 0.0074 - acc: 0.9979 - val_loss: 0.0148 - val_acc: 0.9977
# Epoch 108/1000
# 5s - loss: 0.0069 - acc: 0.9976 - val_loss: 0.0155 - val_acc: 0.9978
# Epoch 109/1000
# 5s - loss: 0.0069 - acc: 0.9978 - val_loss: 0.0148 - val_acc: 0.9978
# Epoch 110/1000
# 5s - loss: 0.0074 - acc: 0.9976 - val_loss: 0.0142 - val_acc: 0.9979
# Epoch 111/1000
# 5s - loss: 0.0079 - acc: 0.9974 - val_loss: 0.0149 - val_acc: 0.9977
# Epoch 112/1000
# 5s - loss: 0.0092 - acc: 0.9974 - val_loss: 0.0149 - val_acc: 0.9979
# Epoch 113/1000
# 5s - loss: 0.0071 - acc: 0.9978 - val_loss: 0.0155 - val_acc: 0.9976
# Epoch 114/1000
# 5s - loss: 0.0091 - acc: 0.9974 - val_loss: 0.0147 - val_acc: 0.9978
# Epoch 115/1000
# 5s - loss: 0.0074 - acc: 0.9981 - val_loss: 0.0143 - val_acc: 0.9979
# Epoch 116/1000
# 5s - loss: 0.0083 - acc: 0.9972 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 117/1000
# 5s - loss: 0.0062 - acc: 0.9978 - val_loss: 0.0139 - val_acc: 0.9981
# Epoch 118/1000
# 5s - loss: 0.0068 - acc: 0.9980 - val_loss: 0.0145 - val_acc: 0.9979
# Epoch 119/1000
# 5s - loss: 0.0069 - acc: 0.9981 - val_loss: 0.0143 - val_acc: 0.9979
# Epoch 120/1000
# 5s - loss: 0.0079 - acc: 0.9976 - val_loss: 0.0140 - val_acc: 0.9979
# Epoch 121/1000
# 5s - loss: 0.0075 - acc: 0.9978 - val_loss: 0.0153 - val_acc: 0.9978
# Epoch 122/1000
# 5s - loss: 0.0069 - acc: 0.9979 - val_loss: 0.0148 - val_acc: 0.9979
# Epoch 123/1000
# 5s - loss: 0.0072 - acc: 0.9978 - val_loss: 0.0148 - val_acc: 0.9977
# Epoch 124/1000
# 5s - loss: 0.0069 - acc: 0.9979 - val_loss: 0.0139 - val_acc: 0.9978
# Epoch 125/1000
# 5s - loss: 0.0072 - acc: 0.9980 - val_loss: 0.0131 - val_acc: 0.9979
# Epoch 126/1000
# 5s - loss: 0.0076 - acc: 0.9981 - val_loss: 0.0133 - val_acc: 0.9978
# Epoch 127/1000
# 5s - loss: 0.0064 - acc: 0.9980 - val_loss: 0.0127 - val_acc: 0.9980
# Epoch 128/1000
# 5s - loss: 0.0062 - acc: 0.9982 - val_loss: 0.0147 - val_acc: 0.9978
# Epoch 129/1000
# 5s - loss: 0.0074 - acc: 0.9976 - val_loss: 0.0137 - val_acc: 0.9978
# Epoch 130/1000
# 5s - loss: 0.0077 - acc: 0.9977 - val_loss: 0.0133 - val_acc: 0.9981
# Epoch 131/1000
# 5s - loss: 0.0070 - acc: 0.9977 - val_loss: 0.0130 - val_acc: 0.9980
# Epoch 132/1000
# 5s - loss: 0.0072 - acc: 0.9976 - val_loss: 0.0125 - val_acc: 0.9981
# Epoch 133/1000
# 5s - loss: 0.0066 - acc: 0.9978 - val_loss: 0.0126 - val_acc: 0.9981
# Epoch 134/1000
# 5s - loss: 0.0075 - acc: 0.9976 - val_loss: 0.0134 - val_acc: 0.9978
# Epoch 135/1000
# 5s - loss: 0.0063 - acc: 0.9980 - val_loss: 0.0119 - val_acc: 0.9979
# Epoch 136/1000
# 5s - loss: 0.0058 - acc: 0.9982 - val_loss: 0.0130 - val_acc: 0.9977
# Epoch 137/1000
# 5s - loss: 0.0064 - acc: 0.9979 - val_loss: 0.0145 - val_acc: 0.9976
# Epoch 138/1000
# 5s - loss: 0.0080 - acc: 0.9977 - val_loss: 0.0128 - val_acc: 0.9981
# Epoch 139/1000
# 5s - loss: 0.0080 - acc: 0.9975 - val_loss: 0.0137 - val_acc: 0.9982
# Epoch 140/1000
# 5s - loss: 0.0066 - acc: 0.9978 - val_loss: 0.0133 - val_acc: 0.9979
# Epoch 141/1000
# 5s - loss: 0.0049 - acc: 0.9983 - val_loss: 0.0137 - val_acc: 0.9980
# Epoch 142/1000
# 5s - loss: 0.0067 - acc: 0.9976 - val_loss: 0.0134 - val_acc: 0.9980
# Epoch 143/1000
# 5s - loss: 0.0051 - acc: 0.9986 - val_loss: 0.0138 - val_acc: 0.9977
# Epoch 144/1000
# 5s - loss: 0.0057 - acc: 0.9984 - val_loss: 0.0134 - val_acc: 0.9981
# Epoch 145/1000
# 5s - loss: 0.0059 - acc: 0.9978 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 146/1000
# 5s - loss: 0.0067 - acc: 0.9982 - val_loss: 0.0133 - val_acc: 0.9981
# Epoch 147/1000
# 5s - loss: 0.0058 - acc: 0.9981 - val_loss: 0.0131 - val_acc: 0.9981
# Epoch 148/1000
# 5s - loss: 0.0077 - acc: 0.9979 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 149/1000
# 5s - loss: 0.0062 - acc: 0.9981 - val_loss: 0.0147 - val_acc: 0.9979
# Epoch 150/1000
# 5s - loss: 0.0062 - acc: 0.9979 - val_loss: 0.0127 - val_acc: 0.9979
# Epoch 151/1000
# 5s - loss: 0.0065 - acc: 0.9981 - val_loss: 0.0128 - val_acc: 0.9981
# Epoch 152/1000
# 5s - loss: 0.0045 - acc: 0.9984 - val_loss: 0.0120 - val_acc: 0.9981
# Epoch 153/1000
# 5s - loss: 0.0069 - acc: 0.9979 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 154/1000
# 5s - loss: 0.0063 - acc: 0.9984 - val_loss: 0.0128 - val_acc: 0.9982
# Epoch 155/1000
# 5s - loss: 0.0055 - acc: 0.9981 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 156/1000
# 5s - loss: 0.0067 - acc: 0.9979 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 157/1000
# 5s - loss: 0.0065 - acc: 0.9982 - val_loss: 0.0131 - val_acc: 0.9982
# Epoch 158/1000
# 5s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0134 - val_acc: 0.9981
# Epoch 159/1000
# 5s - loss: 0.0050 - acc: 0.9983 - val_loss: 0.0133 - val_acc: 0.9979
# Epoch 160/1000
# 5s - loss: 0.0058 - acc: 0.9981 - val_loss: 0.0135 - val_acc: 0.9979
# Epoch 161/1000
# 5s - loss: 0.0054 - acc: 0.9982 - val_loss: 0.0119 - val_acc: 0.9980
# Epoch 162/1000
# 5s - loss: 0.0051 - acc: 0.9980 - val_loss: 0.0133 - val_acc: 0.9979
# Epoch 163/1000
# 5s - loss: 0.0052 - acc: 0.9982 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 164/1000
# 5s - loss: 0.0053 - acc: 0.9984 - val_loss: 0.0122 - val_acc: 0.9981
# Epoch 165/1000
# 5s - loss: 0.0059 - acc: 0.9980 - val_loss: 0.0153 - val_acc: 0.9980
# Epoch 166/1000
# 5s - loss: 0.0061 - acc: 0.9983 - val_loss: 0.0129 - val_acc: 0.9978
# Epoch 167/1000
# 5s - loss: 0.0054 - acc: 0.9983 - val_loss: 0.0146 - val_acc: 0.9979
# Epoch 168/1000
# 5s - loss: 0.0057 - acc: 0.9982 - val_loss: 0.0124 - val_acc: 0.9982
# Epoch 169/1000
# 5s - loss: 0.0059 - acc: 0.9981 - val_loss: 0.0134 - val_acc: 0.9981
# Epoch 170/1000
# 5s - loss: 0.0044 - acc: 0.9985 - val_loss: 0.0123 - val_acc: 0.9981
# Epoch 171/1000
# 5s - loss: 0.0057 - acc: 0.9980 - val_loss: 0.0134 - val_acc: 0.9980
# Epoch 172/1000
# 5s - loss: 0.0065 - acc: 0.9981 - val_loss: 0.0133 - val_acc: 0.9981
# Epoch 173/1000
# 5s - loss: 0.0054 - acc: 0.9981 - val_loss: 0.0127 - val_acc: 0.9981
# Epoch 174/1000
# 5s - loss: 0.0061 - acc: 0.9979 - val_loss: 0.0122 - val_acc: 0.9983
# Epoch 175/1000
# 5s - loss: 0.0065 - acc: 0.9978 - val_loss: 0.0131 - val_acc: 0.9981
# Epoch 176/1000
# 5s - loss: 0.0055 - acc: 0.9982 - val_loss: 0.0130 - val_acc: 0.9983
# Epoch 177/1000
# 5s - loss: 0.0060 - acc: 0.9982 - val_loss: 0.0123 - val_acc: 0.9984
# Epoch 178/1000
# 5s - loss: 0.0050 - acc: 0.9988 - val_loss: 0.0122 - val_acc: 0.9983
# Epoch 179/1000
# 5s - loss: 0.0046 - acc: 0.9983 - val_loss: 0.0126 - val_acc: 0.9981
# Epoch 180/1000
# 5s - loss: 0.0063 - acc: 0.9982 - val_loss: 0.0134 - val_acc: 0.9981
# Epoch 181/1000
# 5s - loss: 0.0047 - acc: 0.9985 - val_loss: 0.0118 - val_acc: 0.9981
# Epoch 182/1000
# 5s - loss: 0.0054 - acc: 0.9982 - val_loss: 0.0127 - val_acc: 0.9982
# Epoch 183/1000
# 5s - loss: 0.0057 - acc: 0.9985 - val_loss: 0.0132 - val_acc: 0.9981
# Epoch 184/1000
# 5s - loss: 0.0060 - acc: 0.9982 - val_loss: 0.0127 - val_acc: 0.9983
# Epoch 185/1000
# 5s - loss: 0.0039 - acc: 0.9988 - val_loss: 0.0136 - val_acc: 0.9981
# Epoch 186/1000
# 5s - loss: 0.0054 - acc: 0.9985 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 187/1000
# 5s - loss: 0.0037 - acc: 0.9987 - val_loss: 0.0142 - val_acc: 0.9979
# Epoch 188/1000
# 5s - loss: 0.0054 - acc: 0.9980 - val_loss: 0.0140 - val_acc: 0.9979
# Epoch 189/1000
# 5s - loss: 0.0058 - acc: 0.9983 - val_loss: 0.0161 - val_acc: 0.9977
# Epoch 190/1000
# 5s - loss: 0.0053 - acc: 0.9984 - val_loss: 0.0144 - val_acc: 0.9978
# Epoch 191/1000
# 5s - loss: 0.0046 - acc: 0.9986 - val_loss: 0.0128 - val_acc: 0.9980
# Epoch 192/1000
# 5s - loss: 0.0056 - acc: 0.9979 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 193/1000
# 5s - loss: 0.0053 - acc: 0.9981 - val_loss: 0.0125 - val_acc: 0.9981
# Epoch 194/1000
# 5s - loss: 0.0065 - acc: 0.9979 - val_loss: 0.0127 - val_acc: 0.9981
# Epoch 195/1000
# 5s - loss: 0.0057 - acc: 0.9983 - val_loss: 0.0139 - val_acc: 0.9980
# Epoch 196/1000
# 5s - loss: 0.0062 - acc: 0.9980 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 197/1000
# 5s - loss: 0.0044 - acc: 0.9986 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 198/1000
# 5s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 199/1000
# 5s - loss: 0.0041 - acc: 0.9986 - val_loss: 0.0127 - val_acc: 0.9982
# Epoch 200/1000
# 5s - loss: 0.0053 - acc: 0.9981 - val_loss: 0.0137 - val_acc: 0.9982
# Epoch 201/1000
# 5s - loss: 0.0043 - acc: 0.9984 - val_loss: 0.0133 - val_acc: 0.9980
# Epoch 202/1000
# 5s - loss: 0.0059 - acc: 0.9982 - val_loss: 0.0133 - val_acc: 0.9981
# Epoch 203/1000
# 5s - loss: 0.0040 - acc: 0.9987 - val_loss: 0.0130 - val_acc: 0.9980
# Epoch 204/1000
# 5s - loss: 0.0059 - acc: 0.9983 - val_loss: 0.0122 - val_acc: 0.9982
# Epoch 205/1000
# 5s - loss: 0.0051 - acc: 0.9985 - val_loss: 0.0133 - val_acc: 0.9984
# Epoch 206/1000
# 5s - loss: 0.0055 - acc: 0.9984 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 207/1000
# 5s - loss: 0.0046 - acc: 0.9983 - val_loss: 0.0133 - val_acc: 0.9980
# Epoch 208/1000
# 5s - loss: 0.0035 - acc: 0.9989 - val_loss: 0.0144 - val_acc: 0.9982
# Epoch 209/1000
# 5s - loss: 0.0043 - acc: 0.9984 - val_loss: 0.0130 - val_acc: 0.9980
# Epoch 210/1000
# 5s - loss: 0.0046 - acc: 0.9987 - val_loss: 0.0139 - val_acc: 0.9979
# Epoch 211/1000
# 5s - loss: 0.0037 - acc: 0.9988 - val_loss: 0.0135 - val_acc: 0.9981
# Epoch 212/1000
# 5s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0128 - val_acc: 0.9981
# Epoch 213/1000
# 5s - loss: 0.0050 - acc: 0.9986 - val_loss: 0.0140 - val_acc: 0.9982
# Epoch 214/1000
# 5s - loss: 0.0056 - acc: 0.9982 - val_loss: 0.0130 - val_acc: 0.9981
# Epoch 215/1000
# 5s - loss: 0.0053 - acc: 0.9982 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 216/1000
# 5s - loss: 0.0047 - acc: 0.9985 - val_loss: 0.0150 - val_acc: 0.9983
# Epoch 217/1000
# 5s - loss: 0.0037 - acc: 0.9987 - val_loss: 0.0148 - val_acc: 0.9981
# Epoch 218/1000
# 5s - loss: 0.0047 - acc: 0.9985 - val_loss: 0.0149 - val_acc: 0.9981
# Epoch 219/1000
# 5s - loss: 0.0059 - acc: 0.9984 - val_loss: 0.0144 - val_acc: 0.9981
# Epoch 220/1000
# 5s - loss: 0.0048 - acc: 0.9985 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 221/1000
# 5s - loss: 0.0035 - acc: 0.9990 - val_loss: 0.0122 - val_acc: 0.9983
# Epoch 222/1000
# 5s - loss: 0.0040 - acc: 0.9986 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 223/1000
# 5s - loss: 0.0050 - acc: 0.9983 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 224/1000
# 5s - loss: 0.0042 - acc: 0.9987 - val_loss: 0.0143 - val_acc: 0.9981
# Epoch 225/1000
# 5s - loss: 0.0040 - acc: 0.9985 - val_loss: 0.0151 - val_acc: 0.9982
# Epoch 226/1000
# 5s - loss: 0.0042 - acc: 0.9986 - val_loss: 0.0142 - val_acc: 0.9982
# Epoch 227/1000
# 5s - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0153 - val_acc: 0.9983
# Epoch 228/1000
# 5s - loss: 0.0043 - acc: 0.9984 - val_loss: 0.0149 - val_acc: 0.9982
# Epoch 229/1000
# 5s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0140 - val_acc: 0.9982
# Epoch 230/1000
# 5s - loss: 0.0050 - acc: 0.9987 - val_loss: 0.0152 - val_acc: 0.9978
# Epoch 231/1000
# 5s - loss: 0.0046 - acc: 0.9987 - val_loss: 0.0131 - val_acc: 0.9984
# Epoch 232/1000
# 5s - loss: 0.0045 - acc: 0.9985 - val_loss: 0.0114 - val_acc: 0.9983
# Epoch 233/1000
# 5s - loss: 0.0039 - acc: 0.9985 - val_loss: 0.0141 - val_acc: 0.9982
# Epoch 234/1000
# 5s - loss: 0.0047 - acc: 0.9987 - val_loss: 0.0131 - val_acc: 0.9983
# Epoch 235/1000
# 5s - loss: 0.0035 - acc: 0.9990 - val_loss: 0.0148 - val_acc: 0.9982
# Epoch 236/1000
# 5s - loss: 0.0045 - acc: 0.9988 - val_loss: 0.0117 - val_acc: 0.9982
# Epoch 237/1000
# 5s - loss: 0.0044 - acc: 0.9985 - val_loss: 0.0130 - val_acc: 0.9983
# Epoch 238/1000
# 5s - loss: 0.0050 - acc: 0.9984 - val_loss: 0.0125 - val_acc: 0.9982
# Epoch 239/1000
# 5s - loss: 0.0034 - acc: 0.9988 - val_loss: 0.0119 - val_acc: 0.9981
# Epoch 240/1000
# 5s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0125 - val_acc: 0.9984
# Epoch 241/1000
# 5s - loss: 0.0034 - acc: 0.9988 - val_loss: 0.0124 - val_acc: 0.9980
# Epoch 242/1000
# 5s - loss: 0.0040 - acc: 0.9986 - val_loss: 0.0117 - val_acc: 0.9982
# Epoch 243/1000
# 5s - loss: 0.0051 - acc: 0.9985 - val_loss: 0.0117 - val_acc: 0.9982
# Epoch 244/1000
# 5s - loss: 0.0045 - acc: 0.9986 - val_loss: 0.0143 - val_acc: 0.9981
# Epoch 245/1000
# 5s - loss: 0.0029 - acc: 0.9990 - val_loss: 0.0128 - val_acc: 0.9984
# Epoch 246/1000
# 6s - loss: 0.0052 - acc: 0.9983 - val_loss: 0.0126 - val_acc: 0.9983
# Epoch 247/1000
# 5s - loss: 0.0040 - acc: 0.9987 - val_loss: 0.0126 - val_acc: 0.9983
# Epoch 248/1000
# 5s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 249/1000
# 5s - loss: 0.0030 - acc: 0.9991 - val_loss: 0.0128 - val_acc: 0.9981
# Epoch 250/1000
# 5s - loss: 0.0049 - acc: 0.9984 - val_loss: 0.0120 - val_acc: 0.9983
# Epoch 251/1000
# 5s - loss: 0.0048 - acc: 0.9985 - val_loss: 0.0132 - val_acc: 0.9980
# Epoch 252/1000
# 5s - loss: 0.0046 - acc: 0.9984 - val_loss: 0.0128 - val_acc: 0.9983
# Epoch 253/1000
# 5s - loss: 0.0042 - acc: 0.9987 - val_loss: 0.0129 - val_acc: 0.9982
# Epoch 254/1000
# 5s - loss: 0.0034 - acc: 0.9991 - val_loss: 0.0154 - val_acc: 0.9979
# Epoch 255/1000
# 5s - loss: 0.0050 - acc: 0.9985 - val_loss: 0.0127 - val_acc: 0.9983
# Epoch 256/1000
# 5s - loss: 0.0032 - acc: 0.9987 - val_loss: 0.0153 - val_acc: 0.9974
# Epoch 257/1000
# 5s - loss: 0.0044 - acc: 0.9985 - val_loss: 0.0125 - val_acc: 0.9977
# Epoch 258/1000
# 5s - loss: 0.0067 - acc: 0.9980 - val_loss: 0.0127 - val_acc: 0.9980
# Epoch 259/1000
# 5s - loss: 0.0035 - acc: 0.9989 - val_loss: 0.0137 - val_acc: 0.9979
# Epoch 260/1000
# 5s - loss: 0.0040 - acc: 0.9988 - val_loss: 0.0122 - val_acc: 0.9982
# Epoch 261/1000
# 5s - loss: 0.0033 - acc: 0.9989 - val_loss: 0.0134 - val_acc: 0.9981
# Epoch 262/1000
# 5s - loss: 0.0044 - acc: 0.9987 - val_loss: 0.0108 - val_acc: 0.9984
# Epoch 263/1000
# 5s - loss: 0.0046 - acc: 0.9984 - val_loss: 0.0118 - val_acc: 0.9983
# Epoch 264/1000
# 5s - loss: 0.0043 - acc: 0.9985 - val_loss: 0.0137 - val_acc: 0.9981
# Epoch 265/1000
# 5s - loss: 0.0033 - acc: 0.9990 - val_loss: 0.0128 - val_acc: 0.9982
# Epoch 266/1000
# 5s - loss: 0.0033 - acc: 0.9989 - val_loss: 0.0119 - val_acc: 0.9982
# Epoch 267/1000
# 5s - loss: 0.0031 - acc: 0.9989 - val_loss: 0.0128 - val_acc: 0.9982
# Epoch 268/1000
# 5s - loss: 0.0048 - acc: 0.9986 - val_loss: 0.0146 - val_acc: 0.9980
# Epoch 269/1000
# 5s - loss: 0.0050 - acc: 0.9985 - val_loss: 0.0154 - val_acc: 0.9980
# Epoch 270/1000
# 5s - loss: 0.0050 - acc: 0.9984 - val_loss: 0.0128 - val_acc: 0.9984
# Epoch 271/1000
# 5s - loss: 0.0036 - acc: 0.9989 - val_loss: 0.0124 - val_acc: 0.9983
# Epoch 272/1000
# 5s - loss: 0.0042 - acc: 0.9985 - val_loss: 0.0125 - val_acc: 0.9981
# Epoch 273/1000
# 5s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0129 - val_acc: 0.9982
# Epoch 274/1000
# 5s - loss: 0.0036 - acc: 0.9989 - val_loss: 0.0131 - val_acc: 0.9981
# Epoch 275/1000
# 5s - loss: 0.0045 - acc: 0.9988 - val_loss: 0.0133 - val_acc: 0.9982
# Epoch 276/1000
# 5s - loss: 0.0037 - acc: 0.9988 - val_loss: 0.0149 - val_acc: 0.9979
# Epoch 277/1000
# 5s - loss: 0.0047 - acc: 0.9985 - val_loss: 0.0125 - val_acc: 0.9982
# Epoch 278/1000
# 5s - loss: 0.0045 - acc: 0.9985 - val_loss: 0.0130 - val_acc: 0.9984
# Epoch 279/1000
# 5s - loss: 0.0029 - acc: 0.9991 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 280/1000
# 5s - loss: 0.0033 - acc: 0.9990 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 281/1000
# 5s - loss: 0.0048 - acc: 0.9986 - val_loss: 0.0136 - val_acc: 0.9980
# Epoch 282/1000
# 5s - loss: 0.0052 - acc: 0.9986 - val_loss: 0.0141 - val_acc: 0.9981
# Epoch 283/1000
# 5s - loss: 0.0030 - acc: 0.9991 - val_loss: 0.0151 - val_acc: 0.9981
# Epoch 284/1000
# 5s - loss: 0.0035 - acc: 0.9990 - val_loss: 0.0140 - val_acc: 0.9980
# Epoch 285/1000
# 5s - loss: 0.0036 - acc: 0.9987 - val_loss: 0.0144 - val_acc: 0.9981
# Epoch 286/1000
# 5s - loss: 0.0028 - acc: 0.9990 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 287/1000
# 5s - loss: 0.0043 - acc: 0.9987 - val_loss: 0.0118 - val_acc: 0.9982
# Epoch 288/1000
# 5s - loss: 0.0027 - acc: 0.9992 - val_loss: 0.0138 - val_acc: 0.9981
# Epoch 289/1000
# 5s - loss: 0.0054 - acc: 0.9984 - val_loss: 0.0136 - val_acc: 0.9980
# Epoch 290/1000
# 5s - loss: 0.0039 - acc: 0.9987 - val_loss: 0.0127 - val_acc: 0.9980
# Epoch 291/1000
# 5s - loss: 0.0043 - acc: 0.9984 - val_loss: 0.0147 - val_acc: 0.9979
# Epoch 292/1000
# 6s - loss: 0.0048 - acc: 0.9985 - val_loss: 0.0143 - val_acc: 0.9979
# Epoch 293/1000
# 6s - loss: 0.0030 - acc: 0.9989 - val_loss: 0.0151 - val_acc: 0.9977
# Epoch 294/1000
# 5s - loss: 0.0027 - acc: 0.9989 - val_loss: 0.0138 - val_acc: 0.9981
# Epoch 295/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0141 - val_acc: 0.9982
# Epoch 296/1000
# 5s - loss: 0.0044 - acc: 0.9984 - val_loss: 0.0142 - val_acc: 0.9979
# Epoch 297/1000
# 5s - loss: 0.0052 - acc: 0.9984 - val_loss: 0.0151 - val_acc: 0.9982
# Epoch 298/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0118 - val_acc: 0.9982
# Epoch 299/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0119 - val_acc: 0.9982
# Epoch 300/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0132 - val_acc: 0.9983
# Epoch 301/1000
# 5s - loss: 0.0046 - acc: 0.9983 - val_loss: 0.0120 - val_acc: 0.9983
# Epoch 302/1000
# 5s - loss: 0.0030 - acc: 0.9991 - val_loss: 0.0142 - val_acc: 0.9980
# Epoch 303/1000
# 5s - loss: 0.0049 - acc: 0.9984 - val_loss: 0.0145 - val_acc: 0.9981
# Epoch 304/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0150 - val_acc: 0.9982
# Epoch 305/1000
# 5s - loss: 0.0045 - acc: 0.9988 - val_loss: 0.0141 - val_acc: 0.9978
# Epoch 306/1000
# 5s - loss: 0.0047 - acc: 0.9984 - val_loss: 0.0137 - val_acc: 0.9980
# Epoch 307/1000
# 5s - loss: 0.0041 - acc: 0.9987 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 308/1000
# 5s - loss: 0.0028 - acc: 0.9990 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 309/1000
# 5s - loss: 0.0044 - acc: 0.9987 - val_loss: 0.0133 - val_acc: 0.9980
# Epoch 310/1000
# 5s - loss: 0.0036 - acc: 0.9989 - val_loss: 0.0147 - val_acc: 0.9981
# Epoch 311/1000
# 5s - loss: 0.0038 - acc: 0.9989 - val_loss: 0.0121 - val_acc: 0.9981
# Epoch 312/1000
# 5s - loss: 0.0027 - acc: 0.9991 - val_loss: 0.0133 - val_acc: 0.9979
# Epoch 313/1000
# 5s - loss: 0.0035 - acc: 0.9989 - val_loss: 0.0140 - val_acc: 0.9981
# Epoch 314/1000
# 5s - loss: 0.0020 - acc: 0.9992 - val_loss: 0.0139 - val_acc: 0.9981
# Epoch 315/1000
# 5s - loss: 0.0035 - acc: 0.9990 - val_loss: 0.0150 - val_acc: 0.9978
# Epoch 316/1000
# 5s - loss: 0.0044 - acc: 0.9983 - val_loss: 0.0132 - val_acc: 0.9979
# Epoch 317/1000
# 5s - loss: 0.0045 - acc: 0.9987 - val_loss: 0.0132 - val_acc: 0.9982
# Epoch 318/1000
# 5s - loss: 0.0041 - acc: 0.9990 - val_loss: 0.0127 - val_acc: 0.9980
# Epoch 319/1000
# 5s - loss: 0.0037 - acc: 0.9988 - val_loss: 0.0144 - val_acc: 0.9979
# Epoch 320/1000
# 5s - loss: 0.0030 - acc: 0.9991 - val_loss: 0.0138 - val_acc: 0.9982
# Epoch 321/1000
# 5s - loss: 0.0033 - acc: 0.9991 - val_loss: 0.0135 - val_acc: 0.9980
# Epoch 322/1000
# 5s - loss: 0.0030 - acc: 0.9989 - val_loss: 0.0138 - val_acc: 0.9982
# Epoch 323/1000
# 5s - loss: 0.0031 - acc: 0.9990 - val_loss: 0.0121 - val_acc: 0.9982
# Epoch 324/1000
# 5s - loss: 0.0027 - acc: 0.9991 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 325/1000
# 5s - loss: 0.0031 - acc: 0.9990 - val_loss: 0.0144 - val_acc: 0.9981
# Epoch 326/1000
# 5s - loss: 0.0043 - acc: 0.9988 - val_loss: 0.0126 - val_acc: 0.9982
# Epoch 327/1000
# 5s - loss: 0.0040 - acc: 0.9988 - val_loss: 0.0152 - val_acc: 0.9980
# Epoch 328/1000
# 5s - loss: 0.0034 - acc: 0.9990 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 329/1000
# 5s - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0137 - val_acc: 0.9982
# Epoch 330/1000
# 5s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0120 - val_acc: 0.9980
# Epoch 331/1000
# 5s - loss: 0.0049 - acc: 0.9986 - val_loss: 0.0127 - val_acc: 0.9982
# Epoch 332/1000
# 5s - loss: 0.0032 - acc: 0.9989 - val_loss: 0.0132 - val_acc: 0.9982
# Epoch 333/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0128 - val_acc: 0.9982
# Epoch 334/1000
# 5s - loss: 0.0047 - acc: 0.9988 - val_loss: 0.0123 - val_acc: 0.9982
# Epoch 335/1000
# 5s - loss: 0.0027 - acc: 0.9995 - val_loss: 0.0131 - val_acc: 0.9983
# Epoch 336/1000
# 5s - loss: 0.0028 - acc: 0.9990 - val_loss: 0.0121 - val_acc: 0.9982
# Epoch 337/1000
# 5s - loss: 0.0031 - acc: 0.9988 - val_loss: 0.0143 - val_acc: 0.9982
# Epoch 338/1000
# 5s - loss: 0.0032 - acc: 0.9988 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 339/1000
# 5s - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0122 - val_acc: 0.9981
# Epoch 340/1000
# 5s - loss: 0.0031 - acc: 0.9989 - val_loss: 0.0133 - val_acc: 0.9982
# Epoch 341/1000
# 5s - loss: 0.0039 - acc: 0.9991 - val_loss: 0.0126 - val_acc: 0.9983
# Epoch 342/1000
# 5s - loss: 0.0031 - acc: 0.9990 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 343/1000
# 5s - loss: 0.0036 - acc: 0.9990 - val_loss: 0.0140 - val_acc: 0.9981
# Epoch 344/1000
# 5s - loss: 0.0037 - acc: 0.9987 - val_loss: 0.0131 - val_acc: 0.9982
# Epoch 345/1000
# 5s - loss: 0.0044 - acc: 0.9986 - val_loss: 0.0175 - val_acc: 0.9980
# Epoch 346/1000
# 5s - loss: 0.0046 - acc: 0.9986 - val_loss: 0.0148 - val_acc: 0.9979
# Epoch 347/1000
# 5s - loss: 0.0030 - acc: 0.9990 - val_loss: 0.0156 - val_acc: 0.9980
# Epoch 348/1000
# 5s - loss: 0.0038 - acc: 0.9987 - val_loss: 0.0149 - val_acc: 0.9981
# Epoch 349/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0156 - val_acc: 0.9980
# Epoch 350/1000
# 5s - loss: 0.0038 - acc: 0.9989 - val_loss: 0.0140 - val_acc: 0.9980
# Epoch 351/1000
# 5s - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0144 - val_acc: 0.9980
# Epoch 352/1000
# 5s - loss: 0.0037 - acc: 0.9987 - val_loss: 0.0137 - val_acc: 0.9981
# Epoch 353/1000
# 5s - loss: 0.0028 - acc: 0.9993 - val_loss: 0.0150 - val_acc: 0.9981
# Epoch 354/1000
# 5s - loss: 0.0054 - acc: 0.9982 - val_loss: 0.0154 - val_acc: 0.9979
# Epoch 355/1000
# 5s - loss: 0.0041 - acc: 0.9987 - val_loss: 0.0136 - val_acc: 0.9981
# Epoch 356/1000
# 5s - loss: 0.0032 - acc: 0.9991 - val_loss: 0.0142 - val_acc: 0.9981
# Epoch 357/1000
# 5s - loss: 0.0037 - acc: 0.9989 - val_loss: 0.0136 - val_acc: 0.9980
# Epoch 358/1000
# 5s - loss: 0.0038 - acc: 0.9991 - val_loss: 0.0142 - val_acc: 0.9981
# Epoch 359/1000
# 5s - loss: 0.0033 - acc: 0.9993 - val_loss: 0.0149 - val_acc: 0.9982
# Epoch 360/1000
# 5s - loss: 0.0031 - acc: 0.9990 - val_loss: 0.0143 - val_acc: 0.9983
# Epoch 361/1000
# 5s - loss: 0.0026 - acc: 0.9993 - val_loss: 0.0144 - val_acc: 0.9982
# Epoch 362/1000
# 5s - loss: 0.0028 - acc: 0.9992 - val_loss: 0.0153 - val_acc: 0.9981
# Epoch 363/1000
# 5s - loss: 0.0027 - acc: 0.9992 - val_loss: 0.0127 - val_acc: 0.9983
# Epoch 364/1000
# 5s - loss: 0.0030 - acc: 0.9991 - val_loss: 0.0127 - val_acc: 0.9984
# Epoch 365/1000
# 5s - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0146 - val_acc: 0.9981
# Epoch 366/1000
# 5s - loss: 0.0037 - acc: 0.9988 - val_loss: 0.0126 - val_acc: 0.9983
# Epoch 367/1000
# 5s - loss: 0.0034 - acc: 0.9989 - val_loss: 0.0128 - val_acc: 0.9983
# Epoch 368/1000
# 5s - loss: 0.0034 - acc: 0.9989 - val_loss: 0.0124 - val_acc: 0.9984
# Epoch 369/1000
# 5s - loss: 0.0029 - acc: 0.9992 - val_loss: 0.0123 - val_acc: 0.9985
# Epoch 370/1000
# 5s - loss: 0.0033 - acc: 0.9990 - val_loss: 0.0119 - val_acc: 0.9983
# Epoch 371/1000
# 5s - loss: 0.0030 - acc: 0.9989 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 372/1000
# 5s - loss: 0.0043 - acc: 0.9985 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 373/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0130 - val_acc: 0.9982
# Epoch 374/1000
# 5s - loss: 0.0026 - acc: 0.9992 - val_loss: 0.0121 - val_acc: 0.9983
# Epoch 375/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0133 - val_acc: 0.9982
# Epoch 376/1000
# 5s - loss: 0.0025 - acc: 0.9993 - val_loss: 0.0115 - val_acc: 0.9983
# Epoch 377/1000
# 5s - loss: 0.0026 - acc: 0.9992 - val_loss: 0.0128 - val_acc: 0.9982
# Epoch 378/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 379/1000
# 5s - loss: 0.0029 - acc: 0.9990 - val_loss: 0.0139 - val_acc: 0.9983
# Epoch 380/1000
# 5s - loss: 0.0028 - acc: 0.9993 - val_loss: 0.0144 - val_acc: 0.9981
# Epoch 381/1000
# 5s - loss: 0.0035 - acc: 0.9989 - val_loss: 0.0127 - val_acc: 0.9982
# Epoch 382/1000
# 5s - loss: 0.0023 - acc: 0.9990 - val_loss: 0.0146 - val_acc: 0.9982
# Epoch 383/1000
# 5s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0134 - val_acc: 0.9984
# Epoch 384/1000
# 5s - loss: 0.0030 - acc: 0.9990 - val_loss: 0.0122 - val_acc: 0.9982
# Epoch 385/1000
# 5s - loss: 0.0032 - acc: 0.9987 - val_loss: 0.0124 - val_acc: 0.9985
# Epoch 386/1000
# 5s - loss: 0.0032 - acc: 0.9993 - val_loss: 0.0126 - val_acc: 0.9985
# Epoch 387/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0139 - val_acc: 0.9983
# Epoch 388/1000
# 5s - loss: 0.0037 - acc: 0.9991 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 389/1000
# 5s - loss: 0.0037 - acc: 0.9987 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 390/1000
# 5s - loss: 0.0035 - acc: 0.9989 - val_loss: 0.0140 - val_acc: 0.9981
# Epoch 391/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0144 - val_acc: 0.9982
# Epoch 392/1000
# 5s - loss: 0.0031 - acc: 0.9991 - val_loss: 0.0136 - val_acc: 0.9981
# Epoch 393/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0135 - val_acc: 0.9982
# Epoch 394/1000
# 5s - loss: 0.0029 - acc: 0.9992 - val_loss: 0.0141 - val_acc: 0.9984
# Epoch 395/1000
# 5s - loss: 0.0032 - acc: 0.9989 - val_loss: 0.0148 - val_acc: 0.9982
# Epoch 396/1000
# 5s - loss: 0.0027 - acc: 0.9991 - val_loss: 0.0138 - val_acc: 0.9983
# Epoch 397/1000
# 5s - loss: 0.0034 - acc: 0.9988 - val_loss: 0.0151 - val_acc: 0.9982
# Epoch 398/1000
# 5s - loss: 0.0034 - acc: 0.9989 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 399/1000
# 5s - loss: 0.0043 - acc: 0.9986 - val_loss: 0.0137 - val_acc: 0.9983
# Epoch 400/1000
# 5s - loss: 0.0025 - acc: 0.9992 - val_loss: 0.0149 - val_acc: 0.9984
# Epoch 401/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0139 - val_acc: 0.9983
# Epoch 402/1000
# 5s - loss: 0.0027 - acc: 0.9993 - val_loss: 0.0158 - val_acc: 0.9983
# Epoch 403/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0145 - val_acc: 0.9982
# Epoch 404/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0147 - val_acc: 0.9981
# Epoch 405/1000
# 5s - loss: 0.0026 - acc: 0.9990 - val_loss: 0.0135 - val_acc: 0.9981
# Epoch 406/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0142 - val_acc: 0.9980
# Epoch 407/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0123 - val_acc: 0.9985
# Epoch 408/1000
# 5s - loss: 0.0027 - acc: 0.9994 - val_loss: 0.0144 - val_acc: 0.9981
# Epoch 409/1000
# 5s - loss: 0.0036 - acc: 0.9988 - val_loss: 0.0122 - val_acc: 0.9984
# Epoch 410/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0123 - val_acc: 0.9984
# Epoch 411/1000
# 5s - loss: 0.0031 - acc: 0.9989 - val_loss: 0.0156 - val_acc: 0.9980
# Epoch 412/1000
# 5s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0149 - val_acc: 0.9980
# Epoch 413/1000
# 5s - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0138 - val_acc: 0.9982
# Epoch 414/1000
# 5s - loss: 0.0038 - acc: 0.9989 - val_loss: 0.0151 - val_acc: 0.9981
# Epoch 415/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0143 - val_acc: 0.9983
# Epoch 416/1000
# 5s - loss: 0.0026 - acc: 0.9992 - val_loss: 0.0140 - val_acc: 0.9984
# Epoch 417/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0144 - val_acc: 0.9983
# Epoch 418/1000
# 5s - loss: 0.0024 - acc: 0.9993 - val_loss: 0.0122 - val_acc: 0.9984
# Epoch 419/1000
# 5s - loss: 0.0027 - acc: 0.9993 - val_loss: 0.0135 - val_acc: 0.9985
# Epoch 420/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0129 - val_acc: 0.9985
# Epoch 421/1000
# 5s - loss: 0.0027 - acc: 0.9992 - val_loss: 0.0148 - val_acc: 0.9985
# Epoch 422/1000
# 5s - loss: 0.0036 - acc: 0.9989 - val_loss: 0.0123 - val_acc: 0.9983
# Epoch 423/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0117 - val_acc: 0.9984
# Epoch 424/1000
# 5s - loss: 0.0025 - acc: 0.9993 - val_loss: 0.0130 - val_acc: 0.9983
# Epoch 425/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0152 - val_acc: 0.9982
# Epoch 426/1000
# 5s - loss: 0.0016 - acc: 0.9994 - val_loss: 0.0145 - val_acc: 0.9982
# Epoch 427/1000
# 5s - loss: 0.0038 - acc: 0.9988 - val_loss: 0.0153 - val_acc: 0.9981
# Epoch 428/1000
# 6s - loss: 0.0028 - acc: 0.9991 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 429/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0139 - val_acc: 0.9982
# Epoch 430/1000
# 5s - loss: 0.0039 - acc: 0.9989 - val_loss: 0.0152 - val_acc: 0.9982
# Epoch 431/1000
# 5s - loss: 0.0030 - acc: 0.9990 - val_loss: 0.0134 - val_acc: 0.9984
# Epoch 432/1000
# 5s - loss: 0.0034 - acc: 0.9989 - val_loss: 0.0125 - val_acc: 0.9981
# Epoch 433/1000
# 5s - loss: 0.0028 - acc: 0.9989 - val_loss: 0.0139 - val_acc: 0.9983
# Epoch 434/1000
# 5s - loss: 0.0026 - acc: 0.9990 - val_loss: 0.0144 - val_acc: 0.9980
# Epoch 435/1000
# 5s - loss: 0.0026 - acc: 0.9992 - val_loss: 0.0157 - val_acc: 0.9981
# Epoch 436/1000
# 5s - loss: 0.0025 - acc: 0.9991 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 437/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0152 - val_acc: 0.9984
# Epoch 438/1000
# 5s - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0155 - val_acc: 0.9981
# Epoch 439/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0161 - val_acc: 0.9982
# Epoch 440/1000
# 5s - loss: 0.0019 - acc: 0.9993 - val_loss: 0.0144 - val_acc: 0.9983
# Epoch 441/1000
# 5s - loss: 0.0025 - acc: 0.9993 - val_loss: 0.0149 - val_acc: 0.9982
# Epoch 442/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0141 - val_acc: 0.9982
# Epoch 443/1000
# 5s - loss: 0.0024 - acc: 0.9993 - val_loss: 0.0147 - val_acc: 0.9980
# Epoch 444/1000
# 5s - loss: 0.0025 - acc: 0.9993 - val_loss: 0.0155 - val_acc: 0.9982
# Epoch 445/1000
# 5s - loss: 0.0032 - acc: 0.9988 - val_loss: 0.0124 - val_acc: 0.9982
# Epoch 446/1000
# 5s - loss: 0.0028 - acc: 0.9991 - val_loss: 0.0140 - val_acc: 0.9983
# Epoch 447/1000
# 5s - loss: 0.0031 - acc: 0.9991 - val_loss: 0.0166 - val_acc: 0.9982
# Epoch 448/1000
# 5s - loss: 0.0027 - acc: 0.9991 - val_loss: 0.0137 - val_acc: 0.9983
# Epoch 449/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0140 - val_acc: 0.9985
# Epoch 450/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 451/1000
# 5s - loss: 0.0021 - acc: 0.9993 - val_loss: 0.0122 - val_acc: 0.9985
# Epoch 452/1000
# 5s - loss: 0.0026 - acc: 0.9994 - val_loss: 0.0132 - val_acc: 0.9985
# Epoch 453/1000
# 5s - loss: 0.0025 - acc: 0.9991 - val_loss: 0.0143 - val_acc: 0.9983
# Epoch 454/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0142 - val_acc: 0.9984
# Epoch 455/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0143 - val_acc: 0.9984
# Epoch 456/1000
# 5s - loss: 0.0021 - acc: 0.9993 - val_loss: 0.0161 - val_acc: 0.9981
# Epoch 457/1000
# 5s - loss: 0.0023 - acc: 0.9995 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 458/1000
# 5s - loss: 0.0026 - acc: 0.9993 - val_loss: 0.0152 - val_acc: 0.9984
# Epoch 459/1000
# 5s - loss: 0.0039 - acc: 0.9988 - val_loss: 0.0156 - val_acc: 0.9982
# Epoch 460/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0147 - val_acc: 0.9982
# Epoch 461/1000
# 5s - loss: 0.0035 - acc: 0.9987 - val_loss: 0.0144 - val_acc: 0.9982
# Epoch 462/1000
# 5s - loss: 0.0025 - acc: 0.9992 - val_loss: 0.0145 - val_acc: 0.9981
# Epoch 463/1000
# 5s - loss: 0.0029 - acc: 0.9992 - val_loss: 0.0130 - val_acc: 0.9983
# Epoch 464/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0135 - val_acc: 0.9983
# Epoch 465/1000
# 5s - loss: 0.0029 - acc: 0.9994 - val_loss: 0.0127 - val_acc: 0.9984
# Epoch 466/1000
# 5s - loss: 0.0026 - acc: 0.9991 - val_loss: 0.0137 - val_acc: 0.9983
# Epoch 467/1000
# 5s - loss: 0.0033 - acc: 0.9990 - val_loss: 0.0136 - val_acc: 0.9981
# Epoch 468/1000
# 5s - loss: 0.0029 - acc: 0.9992 - val_loss: 0.0137 - val_acc: 0.9984
# Epoch 469/1000
# 5s - loss: 0.0030 - acc: 0.9990 - val_loss: 0.0149 - val_acc: 0.9982
# Epoch 470/1000
# 5s - loss: 0.0030 - acc: 0.9991 - val_loss: 0.0172 - val_acc: 0.9983
# Epoch 471/1000
# 5s - loss: 0.0026 - acc: 0.9993 - val_loss: 0.0140 - val_acc: 0.9984
# Epoch 472/1000
# 5s - loss: 0.0026 - acc: 0.9992 - val_loss: 0.0154 - val_acc: 0.9980
# Epoch 473/1000
# 5s - loss: 0.0028 - acc: 0.9990 - val_loss: 0.0137 - val_acc: 0.9983
# Epoch 474/1000
# 5s - loss: 0.0020 - acc: 0.9992 - val_loss: 0.0139 - val_acc: 0.9981
# Epoch 475/1000
# 5s - loss: 0.0026 - acc: 0.9992 - val_loss: 0.0146 - val_acc: 0.9983
# Epoch 476/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0148 - val_acc: 0.9981
# Epoch 477/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0142 - val_acc: 0.9981
# Epoch 478/1000
# 5s - loss: 0.0017 - acc: 0.9996 - val_loss: 0.0163 - val_acc: 0.9981
# Epoch 479/1000
# 5s - loss: 0.0029 - acc: 0.9992 - val_loss: 0.0151 - val_acc: 0.9981
# Epoch 480/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0144 - val_acc: 0.9982
# Epoch 481/1000
# 5s - loss: 0.0029 - acc: 0.9993 - val_loss: 0.0147 - val_acc: 0.9982
# Epoch 482/1000
# 5s - loss: 0.0025 - acc: 0.9992 - val_loss: 0.0137 - val_acc: 0.9982
# Epoch 483/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0124 - val_acc: 0.9984
# Epoch 484/1000
# 5s - loss: 0.0027 - acc: 0.9992 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 485/1000
# 5s - loss: 0.0030 - acc: 0.9993 - val_loss: 0.0128 - val_acc: 0.9980
# Epoch 486/1000
# 5s - loss: 0.0022 - acc: 0.9992 - val_loss: 0.0129 - val_acc: 0.9978
# Epoch 487/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0131 - val_acc: 0.9980
# Epoch 488/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0145 - val_acc: 0.9981
# Epoch 489/1000
# 5s - loss: 0.0031 - acc: 0.9989 - val_loss: 0.0136 - val_acc: 0.9982
# Epoch 490/1000
# 5s - loss: 0.0030 - acc: 0.9990 - val_loss: 0.0128 - val_acc: 0.9981
# Epoch 491/1000
# 5s - loss: 0.0027 - acc: 0.9991 - val_loss: 0.0126 - val_acc: 0.9984
# Epoch 492/1000
# 5s - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0127 - val_acc: 0.9984
# Epoch 493/1000
# 5s - loss: 0.0027 - acc: 0.9991 - val_loss: 0.0117 - val_acc: 0.9985
# Epoch 494/1000
# 5s - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0154 - val_acc: 0.9981
# Epoch 495/1000
# 5s - loss: 0.0034 - acc: 0.9989 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 496/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 497/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 498/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0133 - val_acc: 0.9981
# Epoch 499/1000
# 5s - loss: 0.0025 - acc: 0.9990 - val_loss: 0.0126 - val_acc: 0.9984
# Epoch 500/1000
# 5s - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0134 - val_acc: 0.9985
# Epoch 501/1000
# 5s - loss: 0.0028 - acc: 0.9993 - val_loss: 0.0144 - val_acc: 0.9982
# Epoch 502/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0145 - val_acc: 0.9981
# Epoch 503/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0164 - val_acc: 0.9982
# Epoch 504/1000
# 5s - loss: 0.0032 - acc: 0.9990 - val_loss: 0.0119 - val_acc: 0.9983
# Epoch 505/1000
# 5s - loss: 0.0025 - acc: 0.9991 - val_loss: 0.0135 - val_acc: 0.9981
# Epoch 506/1000
# 5s - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0121 - val_acc: 0.9983
# Epoch 507/1000
# 5s - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0123 - val_acc: 0.9985
# Epoch 508/1000
# 5s - loss: 0.0028 - acc: 0.9992 - val_loss: 0.0120 - val_acc: 0.9983
# Epoch 509/1000
# 5s - loss: 0.0034 - acc: 0.9993 - val_loss: 0.0126 - val_acc: 0.9982
# Epoch 510/1000
# 5s - loss: 0.0030 - acc: 0.9989 - val_loss: 0.0116 - val_acc: 0.9984
# Epoch 511/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0130 - val_acc: 0.9983
# Epoch 512/1000
# 5s - loss: 0.0037 - acc: 0.9990 - val_loss: 0.0132 - val_acc: 0.9982
# Epoch 513/1000
# 5s - loss: 0.0028 - acc: 0.9991 - val_loss: 0.0134 - val_acc: 0.9984
# Epoch 514/1000
# 5s - loss: 0.0016 - acc: 0.9994 - val_loss: 0.0132 - val_acc: 0.9985
# Epoch 515/1000
# 5s - loss: 0.0027 - acc: 0.9992 - val_loss: 0.0125 - val_acc: 0.9982
# Epoch 516/1000
# 5s - loss: 0.0027 - acc: 0.9993 - val_loss: 0.0155 - val_acc: 0.9983
# Epoch 517/1000
# 5s - loss: 0.0027 - acc: 0.9992 - val_loss: 0.0125 - val_acc: 0.9982
# Epoch 518/1000
# 5s - loss: 0.0022 - acc: 0.9991 - val_loss: 0.0142 - val_acc: 0.9981
# Epoch 519/1000
# 5s - loss: 0.0028 - acc: 0.9993 - val_loss: 0.0131 - val_acc: 0.9982
# Epoch 520/1000
# 5s - loss: 0.0024 - acc: 0.9993 - val_loss: 0.0131 - val_acc: 0.9982
# Epoch 521/1000
# 5s - loss: 0.0016 - acc: 0.9994 - val_loss: 0.0140 - val_acc: 0.9980
# Epoch 522/1000
# 6s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0144 - val_acc: 0.9981
# Epoch 523/1000
# 5s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0135 - val_acc: 0.9981
# Epoch 524/1000
# 5s - loss: 0.0019 - acc: 0.9996 - val_loss: 0.0146 - val_acc: 0.9982
# Epoch 525/1000
# 5s - loss: 0.0032 - acc: 0.9993 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 526/1000
# 5s - loss: 0.0040 - acc: 0.9988 - val_loss: 0.0112 - val_acc: 0.9984
# Epoch 527/1000
# 5s - loss: 0.0025 - acc: 0.9991 - val_loss: 0.0134 - val_acc: 0.9983
# Epoch 528/1000
# 5s - loss: 0.0041 - acc: 0.9989 - val_loss: 0.0129 - val_acc: 0.9980
# Epoch 529/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 530/1000
# 5s - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0162 - val_acc: 0.9981
# Epoch 531/1000
# 5s - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0127 - val_acc: 0.9981
# Epoch 532/1000
# 5s - loss: 0.0028 - acc: 0.9993 - val_loss: 0.0119 - val_acc: 0.9982
# Epoch 533/1000
# 5s - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0132 - val_acc: 0.9982
# Epoch 534/1000
# 5s - loss: 0.0012 - acc: 0.9996 - val_loss: 0.0137 - val_acc: 0.9982
# Epoch 535/1000
# 5s - loss: 0.0022 - acc: 0.9992 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 536/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0137 - val_acc: 0.9980
# Epoch 537/1000
# 5s - loss: 0.0031 - acc: 0.9990 - val_loss: 0.0139 - val_acc: 0.9981
# Epoch 538/1000
# 5s - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0145 - val_acc: 0.9983
# Epoch 539/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0138 - val_acc: 0.9983
# Epoch 540/1000
# 5s - loss: 0.0019 - acc: 0.9992 - val_loss: 0.0108 - val_acc: 0.9984
# Epoch 541/1000
# 5s - loss: 0.0033 - acc: 0.9990 - val_loss: 0.0128 - val_acc: 0.9983
# Epoch 542/1000
# 5s - loss: 0.0028 - acc: 0.9994 - val_loss: 0.0126 - val_acc: 0.9981
# Epoch 543/1000
# 5s - loss: 0.0027 - acc: 0.9990 - val_loss: 0.0147 - val_acc: 0.9982
# Epoch 544/1000
# 5s - loss: 0.0025 - acc: 0.9992 - val_loss: 0.0127 - val_acc: 0.9982
# Epoch 545/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0140 - val_acc: 0.9979
# Epoch 546/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0153 - val_acc: 0.9980
# Epoch 547/1000
# 5s - loss: 0.0027 - acc: 0.9990 - val_loss: 0.0141 - val_acc: 0.9983
# Epoch 548/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0137 - val_acc: 0.9981
# Epoch 549/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0125 - val_acc: 0.9980
# Epoch 550/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0127 - val_acc: 0.9983
# Epoch 551/1000
# 5s - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0143 - val_acc: 0.9983
# Epoch 552/1000
# 5s - loss: 0.0028 - acc: 0.9991 - val_loss: 0.0121 - val_acc: 0.9985
# Epoch 553/1000
# 5s - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0121 - val_acc: 0.9981
# Epoch 554/1000
# 5s - loss: 0.0024 - acc: 0.9991 - val_loss: 0.0128 - val_acc: 0.9984
# Epoch 555/1000
# 5s - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0146 - val_acc: 0.9982
# Epoch 556/1000
# 5s - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0130 - val_acc: 0.9982
# Epoch 557/1000
# 5s - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0129 - val_acc: 0.9982
# Epoch 558/1000
# 5s - loss: 0.0034 - acc: 0.9993 - val_loss: 0.0125 - val_acc: 0.9980
# Epoch 559/1000
# 6s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0110 - val_acc: 0.9983
# Epoch 560/1000
# 5s - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0120 - val_acc: 0.9984
# Epoch 561/1000
# 5s - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0138 - val_acc: 0.9982
# Epoch 562/1000
# 5s - loss: 0.0024 - acc: 0.9994 - val_loss: 0.0113 - val_acc: 0.9983
# Epoch 563/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 564/1000
# 5s - loss: 0.0018 - acc: 0.9996 - val_loss: 0.0132 - val_acc: 0.9984
# Epoch 565/1000
# 5s - loss: 0.0024 - acc: 0.9991 - val_loss: 0.0135 - val_acc: 0.9984
# Epoch 566/1000
# 5s - loss: 0.0027 - acc: 0.9993 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 567/1000
# 5s - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0130 - val_acc: 0.9982
# Epoch 568/1000
# 5s - loss: 0.0035 - acc: 0.9991 - val_loss: 0.0109 - val_acc: 0.9984
# Epoch 569/1000
# 5s - loss: 0.0017 - acc: 0.9996 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 570/1000
# 5s - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0118 - val_acc: 0.9984
# Epoch 571/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0118 - val_acc: 0.9983
# Epoch 572/1000
# ...
# Epoch 812/1000
# 5s - loss: 0.0014 - acc: 0.9994 - val_loss: 0.0140 - val_acc: 0.9983
# Epoch 813/1000
# 5s - loss: 9.2575e-04 - acc: 0.9998 - val_loss: 0.0133 - val_acc: 0.9985
# Epoch 814/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0147 - val_acc: 0.9987
# Epoch 815/1000
# 5s - loss: 0.0029 - acc: 0.9993 - val_loss: 0.0131 - val_acc: 0.9987
# Epoch 816/1000
# 5s - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0146 - val_acc: 0.9984
# Epoch 817/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0135 - val_acc: 0.9987
# Epoch 818/1000
# 5s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0151 - val_acc: 0.9985
# Epoch 819/1000
# 5s - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0159 - val_acc: 0.9985
# Epoch 820/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0136 - val_acc: 0.9985
# Epoch 821/1000
# 5s - loss: 0.0022 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9985
# Epoch 822/1000
# 6s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 823/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0130 - val_acc: 0.9985
# Epoch 824/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0131 - val_acc: 0.9983
# Epoch 825/1000
# 5s - loss: 0.0018 - acc: 0.9993 - val_loss: 0.0120 - val_acc: 0.9986
# Epoch 826/1000
# 5s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.0126 - val_acc: 0.9987
# Epoch 827/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0137 - val_acc: 0.9986
# Epoch 828/1000
# 5s - loss: 0.0021 - acc: 0.9993 - val_loss: 0.0135 - val_acc: 0.9985
# Epoch 829/1000
# 5s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0129 - val_acc: 0.9985
# Epoch 830/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0152 - val_acc: 0.9981
# Epoch 831/1000
# 5s - loss: 0.0022 - acc: 0.9995 - val_loss: 0.0151 - val_acc: 0.9983
# Epoch 832/1000
# 5s - loss: 0.0017 - acc: 0.9993 - val_loss: 0.0160 - val_acc: 0.9983
# Epoch 833/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0156 - val_acc: 0.9983
# Epoch 834/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0135 - val_acc: 0.9985
# Epoch 835/1000
# 5s - loss: 0.0020 - acc: 0.9993 - val_loss: 0.0156 - val_acc: 0.9981
# Epoch 836/1000
# 5s - loss: 7.6457e-04 - acc: 0.9997 - val_loss: 0.0130 - val_acc: 0.9982
# Epoch 837/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0157 - val_acc: 0.9982
# Epoch 838/1000
# 5s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.0137 - val_acc: 0.9981
# Epoch 839/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0158 - val_acc: 0.9983
# Epoch 840/1000
# 5s - loss: 0.0021 - acc: 0.9992 - val_loss: 0.0153 - val_acc: 0.9982
# Epoch 841/1000
# 5s - loss: 0.0025 - acc: 0.9992 - val_loss: 0.0162 - val_acc: 0.9982
# Epoch 842/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0140 - val_acc: 0.9985
# Epoch 843/1000
# 5s - loss: 0.0022 - acc: 0.9993 - val_loss: 0.0138 - val_acc: 0.9983
# Epoch 844/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0147 - val_acc: 0.9983
# Epoch 845/1000
# 5s - loss: 0.0014 - acc: 0.9997 - val_loss: 0.0141 - val_acc: 0.9984
# Epoch 846/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0144 - val_acc: 0.9986
# Epoch 847/1000
# 5s - loss: 0.0010 - acc: 0.9997 - val_loss: 0.0145 - val_acc: 0.9985
# Epoch 848/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0143 - val_acc: 0.9982
# Epoch 849/1000
# 5s - loss: 0.0014 - acc: 0.9995 - val_loss: 0.0153 - val_acc: 0.9981
# Epoch 850/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0152 - val_acc: 0.9983
# Epoch 851/1000
# 5s - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0168 - val_acc: 0.9982
# Epoch 852/1000
# 5s - loss: 0.0026 - acc: 0.9993 - val_loss: 0.0175 - val_acc: 0.9982
# Epoch 853/1000
# 5s - loss: 0.0017 - acc: 0.9996 - val_loss: 0.0156 - val_acc: 0.9983
# Epoch 854/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0151 - val_acc: 0.9982
# Epoch 855/1000
# 5s - loss: 0.0017 - acc: 0.9997 - val_loss: 0.0126 - val_acc: 0.9983
# Epoch 856/1000
# 5s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0142 - val_acc: 0.9984
# Epoch 857/1000
# 5s - loss: 0.0016 - acc: 0.9997 - val_loss: 0.0159 - val_acc: 0.9984
# Epoch 858/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0152 - val_acc: 0.9983
# Epoch 859/1000
# 5s - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0132 - val_acc: 0.9984
# Epoch 860/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0120 - val_acc: 0.9985
# Epoch 861/1000
# 5s - loss: 0.0013 - acc: 0.9995 - val_loss: 0.0134 - val_acc: 0.9984
# Epoch 862/1000
# 5s - loss: 5.4027e-04 - acc: 0.9999 - val_loss: 0.0139 - val_acc: 0.9984
# Epoch 863/1000
# 6s - loss: 0.0020 - acc: 0.9994 - val_loss: 0.0131 - val_acc: 0.9984
# Epoch 864/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0140 - val_acc: 0.9983
# Epoch 865/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0139 - val_acc: 0.9985
# Epoch 866/1000
# 5s - loss: 0.0025 - acc: 0.9989 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 867/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9983
# Epoch 868/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0151 - val_acc: 0.9982
# Epoch 869/1000
# 5s - loss: 5.7522e-04 - acc: 0.9998 - val_loss: 0.0157 - val_acc: 0.9982
# Epoch 870/1000
# 5s - loss: 7.8648e-04 - acc: 0.9997 - val_loss: 0.0159 - val_acc: 0.9983
# Epoch 871/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0139 - val_acc: 0.9983
# Epoch 872/1000
# 5s - loss: 0.0016 - acc: 0.9994 - val_loss: 0.0148 - val_acc: 0.9983
# Epoch 873/1000
# 5s - loss: 0.0020 - acc: 0.9994 - val_loss: 0.0139 - val_acc: 0.9984
# Epoch 874/1000
# 5s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.0149 - val_acc: 0.9984
# Epoch 875/1000
# 5s - loss: 0.0012 - acc: 0.9995 - val_loss: 0.0149 - val_acc: 0.9984
# Epoch 876/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0159 - val_acc: 0.9983
# Epoch 877/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0152 - val_acc: 0.9982
# Epoch 878/1000
# 5s - loss: 0.0025 - acc: 0.9994 - val_loss: 0.0153 - val_acc: 0.9985
# Epoch 879/1000
# 5s - loss: 0.0024 - acc: 0.9992 - val_loss: 0.0141 - val_acc: 0.9982
# Epoch 880/1000
# 5s - loss: 0.0025 - acc: 0.9993 - val_loss: 0.0170 - val_acc: 0.9982
# Epoch 881/1000
# 5s - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0135 - val_acc: 0.9984
# Epoch 882/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0145 - val_acc: 0.9983
# Epoch 883/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0169 - val_acc: 0.9982
# Epoch 884/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0145 - val_acc: 0.9980
# Epoch 885/1000
# 5s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.0155 - val_acc: 0.9982
# Epoch 886/1000
# 5s - loss: 0.0018 - acc: 0.9997 - val_loss: 0.0143 - val_acc: 0.9982
# Epoch 887/1000
# 5s - loss: 0.0011 - acc: 0.9995 - val_loss: 0.0148 - val_acc: 0.9983
# Epoch 888/1000
# 5s - loss: 9.7160e-04 - acc: 0.9996 - val_loss: 0.0133 - val_acc: 0.9986
# Epoch 889/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0136 - val_acc: 0.9984
# Epoch 890/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0130 - val_acc: 0.9984
# Epoch 891/1000
# 5s - loss: 9.8463e-04 - acc: 0.9997 - val_loss: 0.0135 - val_acc: 0.9984
# Epoch 892/1000
# 5s - loss: 0.0022 - acc: 0.9996 - val_loss: 0.0129 - val_acc: 0.9986
# Epoch 893/1000
# 5s - loss: 0.0019 - acc: 0.9993 - val_loss: 0.0129 - val_acc: 0.9982
# Epoch 894/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0127 - val_acc: 0.9979
# Epoch 895/1000
# 5s - loss: 9.9333e-04 - acc: 0.9996 - val_loss: 0.0149 - val_acc: 0.9983
# Epoch 896/1000
# 5s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.0147 - val_acc: 0.9984
# Epoch 897/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9984
# Epoch 898/1000
# 5s - loss: 9.3442e-04 - acc: 0.9997 - val_loss: 0.0142 - val_acc: 0.9984
# Epoch 899/1000
# 5s - loss: 0.0019 - acc: 0.9993 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 900/1000
# 5s - loss: 0.0019 - acc: 0.9993 - val_loss: 0.0131 - val_acc: 0.9985
# Epoch 901/1000
# 5s - loss: 0.0017 - acc: 0.9993 - val_loss: 0.0124 - val_acc: 0.9983
# Epoch 902/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9984
# Epoch 903/1000
# 5s - loss: 0.0016 - acc: 0.9993 - val_loss: 0.0158 - val_acc: 0.9982
# Epoch 904/1000
# 5s - loss: 0.0026 - acc: 0.9993 - val_loss: 0.0129 - val_acc: 0.9986
# Epoch 905/1000
# 5s - loss: 0.0010 - acc: 0.9996 - val_loss: 0.0146 - val_acc: 0.9984
# Epoch 906/1000
# 5s - loss: 0.0014 - acc: 0.9995 - val_loss: 0.0128 - val_acc: 0.9987
# Epoch 907/1000
# 5s - loss: 7.8139e-04 - acc: 0.9997 - val_loss: 0.0136 - val_acc: 0.9984
# Epoch 908/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0145 - val_acc: 0.9985
# Epoch 909/1000
# 5s - loss: 0.0013 - acc: 0.9994 - val_loss: 0.0146 - val_acc: 0.9984
# Epoch 910/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0140 - val_acc: 0.9982
# Epoch 911/1000
# 5s - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0137 - val_acc: 0.9983
# Epoch 912/1000
# 5s - loss: 0.0015 - acc: 0.9994 - val_loss: 0.0134 - val_acc: 0.9982
# Epoch 913/1000
# 5s - loss: 6.6286e-04 - acc: 0.9997 - val_loss: 0.0150 - val_acc: 0.9982
# Epoch 914/1000
# 5s - loss: 0.0015 - acc: 0.9997 - val_loss: 0.0139 - val_acc: 0.9981
# Epoch 915/1000
# 5s - loss: 9.1827e-04 - acc: 0.9997 - val_loss: 0.0137 - val_acc: 0.9982
# Epoch 916/1000
# 5s - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0126 - val_acc: 0.9985
# Epoch 917/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0146 - val_acc: 0.9981
# Epoch 918/1000
# 5s - loss: 0.0022 - acc: 0.9995 - val_loss: 0.0150 - val_acc: 0.9982
# Epoch 919/1000
# 5s - loss: 0.0015 - acc: 0.9994 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 920/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0136 - val_acc: 0.9983
# Epoch 921/1000
# 5s - loss: 0.0010 - acc: 0.9996 - val_loss: 0.0140 - val_acc: 0.9983
# Epoch 922/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0129 - val_acc: 0.9983
# Epoch 923/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0145 - val_acc: 0.9980
# Epoch 924/1000
# 5s - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0124 - val_acc: 0.9985
# Epoch 925/1000
# 5s - loss: 0.0012 - acc: 0.9996 - val_loss: 0.0122 - val_acc: 0.9983
# Epoch 926/1000
# 5s - loss: 0.0022 - acc: 0.9995 - val_loss: 0.0123 - val_acc: 0.9982
# Epoch 927/1000
# 5s - loss: 0.0019 - acc: 0.9994 - val_loss: 0.0149 - val_acc: 0.9981
# Epoch 928/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0143 - val_acc: 0.9985
# Epoch 929/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0147 - val_acc: 0.9981
# Epoch 930/1000
# 5s - loss: 8.9984e-04 - acc: 0.9998 - val_loss: 0.0162 - val_acc: 0.9982
# Epoch 931/1000
# 5s - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0133 - val_acc: 0.9983
# Epoch 932/1000
# 5s - loss: 0.0018 - acc: 0.9996 - val_loss: 0.0165 - val_acc: 0.9981
# Epoch 933/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0163 - val_acc: 0.9981
# Epoch 934/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0153 - val_acc: 0.9983
# Epoch 935/1000
# 5s - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0145 - val_acc: 0.9982
# Epoch 936/1000
# 5s - loss: 0.0017 - acc: 0.9996 - val_loss: 0.0149 - val_acc: 0.9982
# Epoch 937/1000
# 5s - loss: 0.0013 - acc: 0.9995 - val_loss: 0.0137 - val_acc: 0.9980
# Epoch 938/1000
# 5s - loss: 0.0018 - acc: 0.9995 - val_loss: 0.0148 - val_acc: 0.9985
# Epoch 939/1000
# 5s - loss: 0.0014 - acc: 0.9995 - val_loss: 0.0129 - val_acc: 0.9981
# Epoch 940/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0125 - val_acc: 0.9984
# Epoch 941/1000
# 5s - loss: 0.0020 - acc: 0.9995 - val_loss: 0.0143 - val_acc: 0.9980
# Epoch 942/1000
# 5s - loss: 0.0023 - acc: 0.9993 - val_loss: 0.0130 - val_acc: 0.9984
# Epoch 943/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0150 - val_acc: 0.9982
# Epoch 944/1000
# 5s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0130 - val_acc: 0.9984
# Epoch 945/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 946/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0139 - val_acc: 0.9985
# Epoch 947/1000
# 5s - loss: 8.2742e-04 - acc: 0.9997 - val_loss: 0.0151 - val_acc: 0.9981
# Epoch 948/1000
# 5s - loss: 0.0022 - acc: 0.9994 - val_loss: 0.0155 - val_acc: 0.9984
# Epoch 949/1000
# 5s - loss: 0.0013 - acc: 0.9995 - val_loss: 0.0136 - val_acc: 0.9986
# Epoch 950/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0138 - val_acc: 0.9983
# Epoch 951/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0131 - val_acc: 0.9983
# Epoch 952/1000
# 5s - loss: 0.0010 - acc: 0.9997 - val_loss: 0.0127 - val_acc: 0.9984
# Epoch 953/1000
# 5s - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0121 - val_acc: 0.9986
# Epoch 954/1000
# 5s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0132 - val_acc: 0.9984
# Epoch 955/1000
# 5s - loss: 0.0018 - acc: 0.9996 - val_loss: 0.0154 - val_acc: 0.9983
# Epoch 956/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0137 - val_acc: 0.9983
# Epoch 957/1000
# 5s - loss: 0.0017 - acc: 0.9994 - val_loss: 0.0153 - val_acc: 0.9982
# Epoch 958/1000
# 5s - loss: 9.7801e-04 - acc: 0.9997 - val_loss: 0.0161 - val_acc: 0.9982
# Epoch 959/1000
# 5s - loss: 0.0022 - acc: 0.9995 - val_loss: 0.0147 - val_acc: 0.9983
# Epoch 960/1000
# 5s - loss: 9.0506e-04 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9981
# Epoch 961/1000
# 5s - loss: 0.0018 - acc: 0.9996 - val_loss: 0.0127 - val_acc: 0.9985
# Epoch 962/1000
# 5s - loss: 0.0011 - acc: 0.9996 - val_loss: 0.0131 - val_acc: 0.9986
# Epoch 963/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0147 - val_acc: 0.9983
# Epoch 964/1000
# 5s - loss: 0.0014 - acc: 0.9995 - val_loss: 0.0148 - val_acc: 0.9984
# Epoch 965/1000
# 5s - loss: 0.0028 - acc: 0.9991 - val_loss: 0.0156 - val_acc: 0.9982
# Epoch 966/1000
# 5s - loss: 0.0017 - acc: 0.9996 - val_loss: 0.0146 - val_acc: 0.9985
# Epoch 967/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0146 - val_acc: 0.9983
# Epoch 968/1000
# 5s - loss: 0.0011 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9985
# Epoch 969/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0145 - val_acc: 0.9983
# Epoch 970/1000
# 5s - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0147 - val_acc: 0.9985
# Epoch 971/1000
# 5s - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0140 - val_acc: 0.9984
# Epoch 972/1000
# 5s - loss: 0.0016 - acc: 0.9994 - val_loss: 0.0141 - val_acc: 0.9985
# Epoch 973/1000
# 5s - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0161 - val_acc: 0.9983
# Epoch 974/1000
# 5s - loss: 0.0012 - acc: 0.9996 - val_loss: 0.0142 - val_acc: 0.9984
# Epoch 975/1000
# 5s - loss: 0.0018 - acc: 0.9994 - val_loss: 0.0172 - val_acc: 0.9983
# Epoch 976/1000
# 5s - loss: 0.0010 - acc: 0.9997 - val_loss: 0.0142 - val_acc: 0.9985
# Epoch 977/1000
# 5s - loss: 0.0013 - acc: 0.9997 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 978/1000
# 5s - loss: 8.8884e-04 - acc: 0.9998 - val_loss: 0.0145 - val_acc: 0.9982
# Epoch 979/1000
# 5s - loss: 0.0013 - acc: 0.9996 - val_loss: 0.0148 - val_acc: 0.9983
# Epoch 980/1000
# 5s - loss: 0.0012 - acc: 0.9996 - val_loss: 0.0140 - val_acc: 0.9982
# Epoch 981/1000
# 5s - loss: 0.0017 - acc: 0.9996 - val_loss: 0.0118 - val_acc: 0.9982
# Epoch 982/1000
# 5s - loss: 0.0012 - acc: 0.9996 - val_loss: 0.0129 - val_acc: 0.9984
# Epoch 983/1000
# 5s - loss: 0.0012 - acc: 0.9997 - val_loss: 0.0145 - val_acc: 0.9984
# Epoch 984/1000
# 5s - loss: 0.0015 - acc: 0.9996 - val_loss: 0.0141 - val_acc: 0.9985
# Epoch 985/1000
# 5s - loss: 0.0011 - acc: 0.9997 - val_loss: 0.0130 - val_acc: 0.9982
# Epoch 986/1000
# 5s - loss: 7.4550e-04 - acc: 0.9998 - val_loss: 0.0140 - val_acc: 0.9984
# Epoch 987/1000
# 5s - loss: 0.0021 - acc: 0.9994 - val_loss: 0.0149 - val_acc: 0.9982
# Epoch 988/1000
# 5s - loss: 0.0017 - acc: 0.9995 - val_loss: 0.0162 - val_acc: 0.9983
# Epoch 989/1000
# 5s - loss: 0.0022 - acc: 0.9995 - val_loss: 0.0145 - val_acc: 0.9982
# Epoch 990/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0140 - val_acc: 0.9981
# Epoch 991/1000
# 5s - loss: 0.0014 - acc: 0.9995 - val_loss: 0.0141 - val_acc: 0.9981
# Epoch 992/1000
# 5s - loss: 5.4589e-04 - acc: 0.9999 - val_loss: 0.0123 - val_acc: 0.9982
# Epoch 993/1000
# 5s - loss: 0.0016 - acc: 0.9995 - val_loss: 0.0156 - val_acc: 0.9982
# Epoch 994/1000
# 5s - loss: 0.0010 - acc: 0.9997 - val_loss: 0.0157 - val_acc: 0.9982
# Epoch 995/1000
# 5s - loss: 0.0021 - acc: 0.9993 - val_loss: 0.0150 - val_acc: 0.9983
# Epoch 996/1000
# 5s - loss: 0.0015 - acc: 0.9995 - val_loss: 0.0147 - val_acc: 0.9983
# Epoch 997/1000
# 5s - loss: 0.0019 - acc: 0.9995 - val_loss: 0.0146 - val_acc: 0.9982
# Epoch 998/1000
# 5s - loss: 0.0032 - acc: 0.9991 - val_loss: 0.0140 - val_acc: 0.9982
# Epoch 999/1000
# 5s - loss: 0.0014 - acc: 0.9996 - val_loss: 0.0156 - val_acc: 0.9983
# Epoch 1000/1000
# 5s - loss: 0.0028 - acc: 0.9995 - val_loss: 0.0129 - val_acc: 0.9983

# %%
model.save(model_name)

# %% [markdown]
# **Best Validation Accuracy:** (0.9948)

# %% [markdown]
# ## Testing
# Once you've picked out your best model, it's time to test it.
#
# Load up the test data and use the [`evaluate()` method](https://keras.io/models/model/#evaluate) to see how well it does.
#
# Hint 1: After you load your test data, don't forget to normalize the input and one-hot encode the output, so it matches the training data.
#
# Hint 2: The `evaluate()` method should return an array of numbers. Use the `metrics_names()` method to get the labels.

# %%
model.evaluate(X_test, Y_test)
# Out:
# 12630/12630 [==============================] - 1s
# [0.13127789783443108, 0.97988915285796097]

# %% [markdown]
# **Test Accuracy:** 0.9799

# %% [markdown]
# This is a pretty good result. With 97.98 % test accuracy we would have come in place 15 of the original 2011 German Traffic Sign Recognition Benchmark Competition, see <a href="http://benchmark.ini.rub.de/?section=gtsrb&subsection=news">GTSRB</a> and . We have not even used data augmentation, any more sophisticated preprocessing of the images or hyperparameter tuning so far and doing so should further improve the results. In order to do this sytematically we would have to check precisely _what_ traffic signs get classified  incorrectly
#
# But for now we'll leave it at that. A great reference of a high scoring submission to the competition (98.97%) is the 2 convolutional layer network that includes also more advanced and interesting features such as layer skipping on <a href="http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf"> Yann LeCun's website</a>

# %% [markdown]
# ## Summary
# Keras is a great tool to use if you want to quickly build a neural network and evaluate performance.
